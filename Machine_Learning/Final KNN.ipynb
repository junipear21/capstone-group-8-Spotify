# %%
import pandas as pd
import numpy as np

from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler


from sklearn.metrics import silhouette_samples, silhouette_score
from pathlib import Path

# %%
# read in file
file1 = 'resources/tracks_df.csv'
tracks_df = pd.read_csv(file1)

# %%
tracks_df.head(5)
# Out:
#                        id                                            name  \
# 0  2G0GextMwZJLkNxcSZ7ZJ3                 (What A) Wonderful World - Mono
# 1  3oAWTk92mZBxKBOKf8mR5v                                Summertime Blues
# 2  2x6pbpjVGjiWCcH89IK8AX                       Breaking Up Is Hard to Do
# 3  47mA6f44zxLtdATOoY7GjN  Georgia on My Mind - Original Master Recording
# 4  0DICNd5XQ1og9UeYzxoNFV                 Baby (You've Got What It Takes)
#
#    popularity  duration_ms  explicit                               artists  \
# 0          67       128787         0                         ['Sam Cooke']
# 1          64       119360         0                     ['Eddie Cochran']
# 2          63       139200         0                       ['Neil Sedaka']
# 3          61       217415         0                       ['Ray Charles']
# 4          60       165760         0  ['Dinah Washington', 'Brook Benton']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1960-02-01         0.686   0.672   11    -5.523     1       0.0323
# 1   1960-05-01         0.714   0.886   11    -8.629     0       0.0554
# 2   1960-12-30         0.743   0.799    8    -5.466     0       0.0375
# 3   1960-09-01         0.138   0.399    7    -8.756     1       0.0311
# 4   1960-07-05         0.670   0.596    3    -9.347     1       0.0627
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.700          0.000000    0.1350    0.857  128.550
# 1         0.116          0.184000    0.1800    0.954  156.351
# 2         0.699          0.000000    0.0635    0.965  116.112
# 3         0.782          0.000004    0.1880    0.296  179.930
# 4         0.852          0.002030    0.6530    0.813  133.396

# %%
tracks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509268 entries, 0 to 509267
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                509268 non-null  object
#  1   name              509268 non-null  object
#  2   popularity        509268 non-null  int64
#  3   duration_ms       509268 non-null  int64
#  4   explicit          509268 non-null  int64
#  5   artists           509268 non-null  object
#  6   release_date      509268 non-null  object
#  7   danceability      509268 non-null  float64
#  8   energy            509268 non-null  float64
#  9   key               509268 non-null  int64
#  10  loudness          509268 non-null  float64
#  11  mode              509268 non-null  int64
#  12  speechiness       509268 non-null  float64
#  13  acousticness      509268 non-null  float64
#  14  instrumentalness  509268 non-null  float64
#  15  liveness          509268 non-null  float64
#  16  valence           509268 non-null  float64
#  17  tempo             509268 non-null  float64
# dtypes: float64(9), int64(5), object(4)
# memory usage: 69.9+ MB

# %%
tracks_df.shape[0]
# Out:
# 509268

# %%
tracks_df=tracks_df.drop_duplicates(subset=['name'])

# %%
tracks_df.shape[0]
# Out:
# 391661

# %%
tracks_df.head()
# Out:
#                        id                                            name  \
# 0  2G0GextMwZJLkNxcSZ7ZJ3                 (What A) Wonderful World - Mono
# 1  3oAWTk92mZBxKBOKf8mR5v                                Summertime Blues
# 2  2x6pbpjVGjiWCcH89IK8AX                       Breaking Up Is Hard to Do
# 3  47mA6f44zxLtdATOoY7GjN  Georgia on My Mind - Original Master Recording
# 4  0DICNd5XQ1og9UeYzxoNFV                 Baby (You've Got What It Takes)
#
#    popularity  duration_ms  explicit                               artists  \
# 0          67       128787         0                         ['Sam Cooke']
# 1          64       119360         0                     ['Eddie Cochran']
# 2          63       139200         0                       ['Neil Sedaka']
# 3          61       217415         0                       ['Ray Charles']
# 4          60       165760         0  ['Dinah Washington', 'Brook Benton']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1960-02-01         0.686   0.672   11    -5.523     1       0.0323
# 1   1960-05-01         0.714   0.886   11    -8.629     0       0.0554
# 2   1960-12-30         0.743   0.799    8    -5.466     0       0.0375
# 3   1960-09-01         0.138   0.399    7    -8.756     1       0.0311
# 4   1960-07-05         0.670   0.596    3    -9.347     1       0.0627
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.700          0.000000    0.1350    0.857  128.550
# 1         0.116          0.184000    0.1800    0.954  156.351
# 2         0.699          0.000000    0.0635    0.965  116.112
# 3         0.782          0.000004    0.1880    0.296  179.930
# 4         0.852          0.002030    0.6530    0.813  133.396

# %%
top_tracks_df = tracks_df[tracks_df["popularity"]>= 80]

# %%
top_tracks_df.head()
# Out:
#                           id                                  name  \
# 4382  745H5CctFr12Mo7cqa1BMH                               My Girl
# 6382  7tqhbajSfrz2F7E1Z75ASX         Ain't No Mountain High Enough
# 6383  3yrSvpt2l1xhsV9Em88Pul                       Brown Eyed Girl
# 8372  6dGnYIeXmHdcikdzNNDMm2  Here Comes The Sun - Remastered 2009
# 8373  4BP3uh0hFLFRb5cjsgLqDh                         Fortunate Son
#
#       popularity  duration_ms  explicit                           artists  \
# 4382          80       165000         0               ['The Temptations']
# 6382          82       151667         0  ['Marvin Gaye', 'Tammi Terrell']
# 6383          80       183307         0                  ['Van Morrison']
# 8372          83       185733         0                   ['The Beatles']
# 8373          83       140773         0  ['Creedence Clearwater Revival']
#
#      release_date  danceability  energy  key  loudness  mode  speechiness  \
# 4382   1965-03-22         0.572   0.418    0   -10.738     1       0.0349
# 6382   1967-08-29         0.663   0.600    7   -10.870     1       0.0320
# 6383   1967-09-01         0.491   0.583    7   -10.964     1       0.0376
# 8372   1969-09-26         0.557   0.540    9   -10.484     1       0.0347
# 8373   1969-11-02         0.640   0.663    0    -7.516     1       0.0374
#
#       acousticness  instrumentalness  liveness  valence    tempo
# 4382        0.6350           0.00000    0.0961    0.694  104.566
# 6382        0.4300           0.00000    0.1840    0.800  129.991
# 6383        0.1820           0.00000    0.4070    0.907  150.572
# 8372        0.0339           0.00248    0.1790    0.394  129.171
# 8373        0.2010           0.00806    0.1520    0.663  132.770

# %%
filepath = Path('Resources/KNN_top_tracks.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
top_tracks_df.to_csv(filepath)

# %%
file2 = 'resources/KNN_top_tracks.csv'
KNN_top_tracks = pd.read_csv(file2)

# %%
KNN_top_tracks.head()
# Out:
#    Unnamed: 0                      id                                  name  \
# 0        4382  745H5CctFr12Mo7cqa1BMH                               My Girl
# 1        6382  7tqhbajSfrz2F7E1Z75ASX         Ain't No Mountain High Enough
# 2        6383  3yrSvpt2l1xhsV9Em88Pul                       Brown Eyed Girl
# 3        8372  6dGnYIeXmHdcikdzNNDMm2  Here Comes The Sun - Remastered 2009
# 4        8373  4BP3uh0hFLFRb5cjsgLqDh                         Fortunate Son
#
#    popularity  duration_ms  explicit                           artists  \
# 0          80       165000         0               ['The Temptations']
# 1          82       151667         0  ['Marvin Gaye', 'Tammi Terrell']
# 2          80       183307         0                  ['Van Morrison']
# 3          83       185733         0                   ['The Beatles']
# 4          83       140773         0  ['Creedence Clearwater Revival']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1965-03-22         0.572   0.418    0   -10.738     1       0.0349
# 1   1967-08-29         0.663   0.600    7   -10.870     1       0.0320
# 2   1967-09-01         0.491   0.583    7   -10.964     1       0.0376
# 3   1969-09-26         0.557   0.540    9   -10.484     1       0.0347
# 4   1969-11-02         0.640   0.663    0    -7.516     1       0.0374
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.6350           0.00000    0.0961    0.694  104.566
# 1        0.4300           0.00000    0.1840    0.800  129.991
# 2        0.1820           0.00000    0.4070    0.907  150.572
# 3        0.0339           0.00248    0.1790    0.394  129.171
# 4        0.2010           0.00806    0.1520    0.663  132.770

# %%
KNN_top_tracks_alpha = pd.read_csv(file2)

# %%
KNN_top_tracks_alpha.head()
# Out:
#    Unnamed: 0                      id                                  name  \
# 0        4382  745H5CctFr12Mo7cqa1BMH                               My Girl
# 1        6382  7tqhbajSfrz2F7E1Z75ASX         Ain't No Mountain High Enough
# 2        6383  3yrSvpt2l1xhsV9Em88Pul                       Brown Eyed Girl
# 3        8372  6dGnYIeXmHdcikdzNNDMm2  Here Comes The Sun - Remastered 2009
# 4        8373  4BP3uh0hFLFRb5cjsgLqDh                         Fortunate Son
#
#    popularity  duration_ms  explicit                           artists  \
# 0          80       165000         0               ['The Temptations']
# 1          82       151667         0  ['Marvin Gaye', 'Tammi Terrell']
# 2          80       183307         0                  ['Van Morrison']
# 3          83       185733         0                   ['The Beatles']
# 4          83       140773         0  ['Creedence Clearwater Revival']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1965-03-22         0.572   0.418    0   -10.738     1       0.0349
# 1   1967-08-29         0.663   0.600    7   -10.870     1       0.0320
# 2   1967-09-01         0.491   0.583    7   -10.964     1       0.0376
# 3   1969-09-26         0.557   0.540    9   -10.484     1       0.0347
# 4   1969-11-02         0.640   0.663    0    -7.516     1       0.0374
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.6350           0.00000    0.0961    0.694  104.566
# 1        0.4300           0.00000    0.1840    0.800  129.991
# 2        0.1820           0.00000    0.4070    0.907  150.572
# 3        0.0339           0.00248    0.1790    0.394  129.171
# 4        0.2010           0.00806    0.1520    0.663  132.770

# %%
KNN_top_tracks = KNN_top_tracks.drop(['Unnamed: 0'], axis=1)

# %%
KNN_top_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                782 non-null    object
#  1   name              782 non-null    object
#  2   popularity        782 non-null    int64
#  3   duration_ms       782 non-null    int64
#  4   explicit          782 non-null    int64
#  5   artists           782 non-null    object
#  6   release_date      782 non-null    object
#  7   danceability      782 non-null    float64
#  8   energy            782 non-null    float64
#  9   key               782 non-null    int64
#  10  loudness          782 non-null    float64
#  11  mode              782 non-null    int64
#  12  speechiness       782 non-null    float64
#  13  acousticness      782 non-null    float64
#  14  instrumentalness  782 non-null    float64
#  15  liveness          782 non-null    float64
#  16  valence           782 non-null    float64
#  17  tempo             782 non-null    float64
# dtypes: float64(9), int64(5), object(4)
# memory usage: 110.1+ KB

# %%
KNN_top_tracks.head()
# Out:
#                        id                                  name  popularity  \
# 0  745H5CctFr12Mo7cqa1BMH                               My Girl          80
# 1  7tqhbajSfrz2F7E1Z75ASX         Ain't No Mountain High Enough          82
# 2  3yrSvpt2l1xhsV9Em88Pul                       Brown Eyed Girl          80
# 3  6dGnYIeXmHdcikdzNNDMm2  Here Comes The Sun - Remastered 2009          83
# 4  4BP3uh0hFLFRb5cjsgLqDh                         Fortunate Son          83
#
#    duration_ms  explicit                           artists release_date  \
# 0       165000         0               ['The Temptations']   1965-03-22
# 1       151667         0  ['Marvin Gaye', 'Tammi Terrell']   1967-08-29
# 2       183307         0                  ['Van Morrison']   1967-09-01
# 3       185733         0                   ['The Beatles']   1969-09-26
# 4       140773         0  ['Creedence Clearwater Revival']   1969-11-02
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.572   0.418    0   -10.738     1       0.0349        0.6350
# 1         0.663   0.600    7   -10.870     1       0.0320        0.4300
# 2         0.491   0.583    7   -10.964     1       0.0376        0.1820
# 3         0.557   0.540    9   -10.484     1       0.0347        0.0339
# 4         0.640   0.663    0    -7.516     1       0.0374        0.2010
#
#    instrumentalness  liveness  valence    tempo
# 0           0.00000    0.0961    0.694  104.566
# 1           0.00000    0.1840    0.800  129.991
# 2           0.00000    0.4070    0.907  150.572
# 3           0.00248    0.1790    0.394  129.171
# 4           0.00806    0.1520    0.663  132.770

# %%
KNN_top_tracks_index=KNN_top_tracks
KNN_top_tracks_index.index = KNN_top_tracks_index['name']

# %%
KNN_top_tracks_index.head()
# Out:
#                                                           id  \
# name
# My Girl                               745H5CctFr12Mo7cqa1BMH
# Ain't No Mountain High Enough         7tqhbajSfrz2F7E1Z75ASX
# Brown Eyed Girl                       3yrSvpt2l1xhsV9Em88Pul
# Here Comes The Sun - Remastered 2009  6dGnYIeXmHdcikdzNNDMm2
# Fortunate Son                         4BP3uh0hFLFRb5cjsgLqDh
#
#                                                                       name  \
# name
# My Girl                                                            My Girl
# Ain't No Mountain High Enough                Ain't No Mountain High Enough
# Brown Eyed Girl                                            Brown Eyed Girl
# Here Comes The Sun - Remastered 2009  Here Comes The Sun - Remastered 2009
# Fortunate Son                                                Fortunate Son
#
#                                       popularity  duration_ms  explicit  \
# name
# My Girl                                       80       165000         0
# Ain't No Mountain High Enough                 82       151667         0
# Brown Eyed Girl                               80       183307         0
# Here Comes The Sun - Remastered 2009          83       185733         0
# Fortunate Son                                 83       140773         0
#
#                                                                artists  \
# name
# My Girl                                            ['The Temptations']
# Ain't No Mountain High Enough         ['Marvin Gaye', 'Tammi Terrell']
# Brown Eyed Girl                                       ['Van Morrison']
# Here Comes The Sun - Remastered 2009                   ['The Beatles']
# Fortunate Son                         ['Creedence Clearwater Revival']
#
#                                      release_date  danceability  energy  key  \
# name
# My Girl                                1965-03-22         0.572   0.418    0
# Ain't No Mountain High Enough          1967-08-29         0.663   0.600    7
# Brown Eyed Girl                        1967-09-01         0.491   0.583    7
# Here Comes The Sun - Remastered 2009   1969-09-26         0.557   0.540    9
# Fortunate Son                          1969-11-02         0.640   0.663    0
#
#                                       loudness  mode  speechiness  \
# name
# My Girl                                -10.738     1       0.0349
# Ain't No Mountain High Enough          -10.870     1       0.0320
# Brown Eyed Girl                        -10.964     1       0.0376
# Here Comes The Sun - Remastered 2009   -10.484     1       0.0347
# Fortunate Son                           -7.516     1       0.0374
#
#                                       acousticness  instrumentalness  \
# name
# My Girl                                     0.6350           0.00000
# Ain't No Mountain High Enough               0.4300           0.00000
# Brown Eyed Girl                             0.1820           0.00000
# Here Comes The Sun - Remastered 2009        0.0339           0.00248
# Fortunate Son                               0.2010           0.00806
#
#                                       liveness  valence    tempo
# name
# My Girl                                 0.0961    0.694  104.566
# Ain't No Mountain High Enough           0.1840    0.800  129.991
# Brown Eyed Girl                         0.4070    0.907  150.572
# Here Comes The Sun - Remastered 2009    0.1790    0.394  129.171
# Fortunate Son                           0.1520    0.663  132.770

# %%
KNN_top_tracks_index.drop(['name'], axis=1)
# Out:
#                                                                 id  \
# name
# My Girl                                     745H5CctFr12Mo7cqa1BMH
# Ain't No Mountain High Enough               7tqhbajSfrz2F7E1Z75ASX
# Brown Eyed Girl                             3yrSvpt2l1xhsV9Em88Pul
# Here Comes The Sun - Remastered 2009        6dGnYIeXmHdcikdzNNDMm2
# Fortunate Son                               4BP3uh0hFLFRb5cjsgLqDh
# ...                                                            ...
# Still into You                              1yjY7rpaAQvKwpdUliHx0d
# We Don't Talk Anymore (feat. Selena Gomez)  06KyNuuMOX1ROXRhj787tj
# Teeth                                       26wLOs3ZuHJa2Ihhx6QIE6
# Intentions (feat. Quavo)                    4umIPjkehX1r7uhmGvXiSV
# Best Friend (feat. Doja Cat)                2etHQJxIbV0soyPhelVs9Y
#
#                                             popularity  duration_ms  explicit  \
# name
# My Girl                                             80       165000         0
# Ain't No Mountain High Enough                       82       151667         0
# Brown Eyed Girl                                     80       183307         0
# Here Comes The Sun - Remastered 2009                83       185733         0
# Fortunate Son                                       83       140773         0
# ...                                                ...          ...       ...
# Still into You                                      80       216013         0
# We Don't Talk Anymore (feat. Selena Gomez)          80       217707         0
# Teeth                                               80       204887         0
# Intentions (feat. Quavo)                            81       212867         0
# Best Friend (feat. Doja Cat)                        90       155884         1
#
#                                                                      artists  \
# name
# My Girl                                                  ['The Temptations']
# Ain't No Mountain High Enough               ['Marvin Gaye', 'Tammi Terrell']
# Brown Eyed Girl                                             ['Van Morrison']
# Here Comes The Sun - Remastered 2009                         ['The Beatles']
# Fortunate Son                               ['Creedence Clearwater Revival']
# ...                                                                      ...
# Still into You                                                  ['Paramore']
# We Don't Talk Anymore (feat. Selena Gomez)  ['Charlie Puth', 'Selena Gomez']
# Teeth                                                ['5 Seconds of Summer']
# Intentions (feat. Quavo)                          ['Justin Bieber', 'Quavo']
# Best Friend (feat. Doja Cat)                        ['Saweetie', 'Doja Cat']
#
#                                            release_date  danceability  energy  \
# name
# My Girl                                      1965-03-22         0.572   0.418
# Ain't No Mountain High Enough                1967-08-29         0.663   0.600
# Brown Eyed Girl                              1967-09-01         0.491   0.583
# Here Comes The Sun - Remastered 2009         1969-09-26         0.557   0.540
# Fortunate Son                                1969-11-02         0.640   0.663
# ...                                                 ...           ...     ...
# Still into You                               2013-04-05         0.602   0.923
# We Don't Talk Anymore (feat. Selena Gomez)   2016-01-29         0.728   0.563
# Teeth                                        2019-08-23         0.749   0.461
# Intentions (feat. Quavo)                     2020-02-14         0.806   0.546
# Best Friend (feat. Doja Cat)                 2021-01-07         0.840   0.766
#
#                                             key  loudness  mode  speechiness  \
# name
# My Girl                                       0   -10.738     1       0.0349
# Ain't No Mountain High Enough                 7   -10.870     1       0.0320
# Brown Eyed Girl                               7   -10.964     1       0.0376
# Here Comes The Sun - Remastered 2009          9   -10.484     1       0.0347
# Fortunate Son                                 0    -7.516     1       0.0374
# ...                                         ...       ...   ...          ...
# Still into You                                5    -3.763     1       0.0440
# We Don't Talk Anymore (feat. Selena Gomez)    1    -8.053     0       0.1340
# Teeth                                        10    -2.961     0       0.0416
# Intentions (feat. Quavo)                      9    -6.637     1       0.0575
# Best Friend (feat. Doja Cat)                  4    -4.120     1       0.1360
#
#                                             acousticness  instrumentalness  \
# name
# My Girl                                          0.63500          0.000000
# Ain't No Mountain High Enough                    0.43000          0.000000
# Brown Eyed Girl                                  0.18200          0.000000
# Here Comes The Sun - Remastered 2009             0.03390          0.002480
# Fortunate Son                                    0.20100          0.008060
# ...                                                  ...               ...
# Still into You                                   0.00980          0.000000
# We Don't Talk Anymore (feat. Selena Gomez)       0.62100          0.000000
# Teeth                                            0.05160          0.000006
# Intentions (feat. Quavo)                         0.30000          0.000000
# Best Friend (feat. Doja Cat)                     0.00302          0.000004
#
#                                             liveness  valence    tempo
# name
# My Girl                                       0.0961    0.694  104.566
# Ain't No Mountain High Enough                 0.1840    0.800  129.991
# Brown Eyed Girl                               0.4070    0.907  150.572
# Here Comes The Sun - Remastered 2009          0.1790    0.394  129.171
# Fortunate Son                                 0.1520    0.663  132.770
# ...                                              ...      ...      ...
# Still into You                                0.0561    0.765  136.010
# We Don't Talk Anymore (feat. Selena Gomez)    0.1790    0.352  100.017
# Teeth                                         0.0738    0.420  139.020
# Intentions (feat. Quavo)                      0.1020    0.874  147.986
# Best Friend (feat. Doja Cat)                  0.0684    0.402   94.018
#
# [782 rows x 17 columns]

# %%
#tracks_index_df = tracks_df

# %%
#tracks_index_df.head()

# %%
#tracks_df2 = tracks_df
#top_tracks_df2 = tracks_df2

# %%
#tracks_df2.head()

# %%
#tracks_df.index = tracks_df['id']

# %%
#tracks_df = tracks_df.drop(['id'], axis=1)

# %%
#tracks_df.head()

# %%
#top_tracks_df = tracks_df

# %%
#top_tracks_df.head()

# %%
KNN_top_tracks_proc=KNN_top_tracks.drop(['energy','key','mode','speechiness','acousticness','instrumentalness','liveness', 'valence', 'release_date'], axis=1)

# %%
KNN_top_tracks_proc
# Out:
#                                                                 id  \
# name
# My Girl                                     745H5CctFr12Mo7cqa1BMH
# Ain't No Mountain High Enough               7tqhbajSfrz2F7E1Z75ASX
# Brown Eyed Girl                             3yrSvpt2l1xhsV9Em88Pul
# Here Comes The Sun - Remastered 2009        6dGnYIeXmHdcikdzNNDMm2
# Fortunate Son                               4BP3uh0hFLFRb5cjsgLqDh
# ...                                                            ...
# Still into You                              1yjY7rpaAQvKwpdUliHx0d
# We Don't Talk Anymore (feat. Selena Gomez)  06KyNuuMOX1ROXRhj787tj
# Teeth                                       26wLOs3ZuHJa2Ihhx6QIE6
# Intentions (feat. Quavo)                    4umIPjkehX1r7uhmGvXiSV
# Best Friend (feat. Doja Cat)                2etHQJxIbV0soyPhelVs9Y
#
#                                                                                   name  \
# name
# My Girl                                                                        My Girl
# Ain't No Mountain High Enough                            Ain't No Mountain High Enough
# Brown Eyed Girl                                                        Brown Eyed Girl
# Here Comes The Sun - Remastered 2009              Here Comes The Sun - Remastered 2009
# Fortunate Son                                                            Fortunate Son
# ...                                                                                ...
# Still into You                                                          Still into You
# We Don't Talk Anymore (feat. Selena Gomez)  We Don't Talk Anymore (feat. Selena Gomez)
# Teeth                                                                            Teeth
# Intentions (feat. Quavo)                                      Intentions (feat. Quavo)
# Best Friend (feat. Doja Cat)                              Best Friend (feat. Doja Cat)
#
#                                             popularity  duration_ms  explicit  \
# name
# My Girl                                             80       165000         0
# Ain't No Mountain High Enough                       82       151667         0
# Brown Eyed Girl                                     80       183307         0
# Here Comes The Sun - Remastered 2009                83       185733         0
# Fortunate Son                                       83       140773         0
# ...                                                ...          ...       ...
# Still into You                                      80       216013         0
# We Don't Talk Anymore (feat. Selena Gomez)          80       217707         0
# Teeth                                               80       204887         0
# Intentions (feat. Quavo)                            81       212867         0
# Best Friend (feat. Doja Cat)                        90       155884         1
#
#                                                                      artists  \
# name
# My Girl                                                  ['The Temptations']
# Ain't No Mountain High Enough               ['Marvin Gaye', 'Tammi Terrell']
# Brown Eyed Girl                                             ['Van Morrison']
# Here Comes The Sun - Remastered 2009                         ['The Beatles']
# Fortunate Son                               ['Creedence Clearwater Revival']
# ...                                                                      ...
# Still into You                                                  ['Paramore']
# We Don't Talk Anymore (feat. Selena Gomez)  ['Charlie Puth', 'Selena Gomez']
# Teeth                                                ['5 Seconds of Summer']
# Intentions (feat. Quavo)                          ['Justin Bieber', 'Quavo']
# Best Friend (feat. Doja Cat)                        ['Saweetie', 'Doja Cat']
#
#                                             danceability  loudness    tempo
# name
# My Girl                                            0.572   -10.738  104.566
# Ain't No Mountain High Enough                      0.663   -10.870  129.991
# Brown Eyed Girl                                    0.491   -10.964  150.572
# Here Comes The Sun - Remastered 2009               0.557   -10.484  129.171
# Fortunate Son                                      0.640    -7.516  132.770
# ...                                                  ...       ...      ...
# Still into You                                     0.602    -3.763  136.010
# We Don't Talk Anymore (feat. Selena Gomez)         0.728    -8.053  100.017
# Teeth                                              0.749    -2.961  139.020
# Intentions (feat. Quavo)                           0.806    -6.637  147.986
# Best Friend (feat. Doja Cat)                       0.840    -4.120   94.018
#
# [782 rows x 9 columns]

# %%
KNN_top_tracks_proc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 782 entries, My Girl to Best Friend (feat. Doja Cat)
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            782 non-null    object
#  1   name          782 non-null    object
#  2   popularity    782 non-null    int64
#  3   duration_ms   782 non-null    int64
#  4   explicit      782 non-null    int64
#  5   artists       782 non-null    object
#  6   danceability  782 non-null    float64
#  7   loudness      782 non-null    float64
#  8   tempo         782 non-null    float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 61.1+ KB

# %%
#proctop_tracks_df = top_tracks_df.drop(['name','artists'], axis=1)

# %%
#top_tracks_df.info()

# %%
#top_tracks_df.head()

# %%
KNN_top_tracks_proc["popularity"] = KNN_top_tracks_proc["popularity"].astype(float)
KNN_top_tracks_proc["duration_ms"] = KNN_top_tracks_proc["duration_ms"].astype(float)
KNN_top_tracks_proc["explicit"] = KNN_top_tracks_proc["explicit"].astype(float)

# %%
KNN_top_tracks_proc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 782 entries, My Girl to Best Friend (feat. Doja Cat)
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            782 non-null    object
#  1   name          782 non-null    object
#  2   popularity    782 non-null    float64
#  3   duration_ms   782 non-null    float64
#  4   explicit      782 non-null    float64
#  5   artists       782 non-null    object
#  6   danceability  782 non-null    float64
#  7   loudness      782 non-null    float64
#  8   tempo         782 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 61.1+ KB

# %%
KNN_top_tracks_proc.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'danceability', 'loudness', 'tempo'],
#       dtype='object')

# %%
KNN_top_tracks_proc.head()
# Out:
#                                                           id  \
# name
# My Girl                               745H5CctFr12Mo7cqa1BMH
# Ain't No Mountain High Enough         7tqhbajSfrz2F7E1Z75ASX
# Brown Eyed Girl                       3yrSvpt2l1xhsV9Em88Pul
# Here Comes The Sun - Remastered 2009  6dGnYIeXmHdcikdzNNDMm2
# Fortunate Son                         4BP3uh0hFLFRb5cjsgLqDh
#
#                                                                       name  \
# name
# My Girl                                                            My Girl
# Ain't No Mountain High Enough                Ain't No Mountain High Enough
# Brown Eyed Girl                                            Brown Eyed Girl
# Here Comes The Sun - Remastered 2009  Here Comes The Sun - Remastered 2009
# Fortunate Son                                                Fortunate Son
#
#                                       popularity  duration_ms  explicit  \
# name
# My Girl                                     80.0     165000.0       0.0
# Ain't No Mountain High Enough               82.0     151667.0       0.0
# Brown Eyed Girl                             80.0     183307.0       0.0
# Here Comes The Sun - Remastered 2009        83.0     185733.0       0.0
# Fortunate Son                               83.0     140773.0       0.0
#
#                                                                artists  \
# name
# My Girl                                            ['The Temptations']
# Ain't No Mountain High Enough         ['Marvin Gaye', 'Tammi Terrell']
# Brown Eyed Girl                                       ['Van Morrison']
# Here Comes The Sun - Remastered 2009                   ['The Beatles']
# Fortunate Son                         ['Creedence Clearwater Revival']
#
#                                       danceability  loudness    tempo
# name
# My Girl                                      0.572   -10.738  104.566
# Ain't No Mountain High Enough                0.663   -10.870  129.991
# Brown Eyed Girl                              0.491   -10.964  150.572
# Here Comes The Sun - Remastered 2009         0.557   -10.484  129.171
# Fortunate Son                                0.640    -7.516  132.770

# %%
KNN_top_tracks_proc[['popularity', 'danceability', 'loudness', 'tempo']]= StandardScaler().fit_transform(KNN_top_tracks_proc[['popularity', 'danceability', 'loudness', 'tempo']])

# %%
KNN_top_tracks_proc.head()
# Out:
#                                                           id  \
# name
# My Girl                               745H5CctFr12Mo7cqa1BMH
# Ain't No Mountain High Enough         7tqhbajSfrz2F7E1Z75ASX
# Brown Eyed Girl                       3yrSvpt2l1xhsV9Em88Pul
# Here Comes The Sun - Remastered 2009  6dGnYIeXmHdcikdzNNDMm2
# Fortunate Son                         4BP3uh0hFLFRb5cjsgLqDh
#
#                                                                       name  \
# name
# My Girl                                                            My Girl
# Ain't No Mountain High Enough                Ain't No Mountain High Enough
# Brown Eyed Girl                                            Brown Eyed Girl
# Here Comes The Sun - Remastered 2009  Here Comes The Sun - Remastered 2009
# Fortunate Son                                                Fortunate Son
#
#                                       popularity  duration_ms  explicit  \
# name
# My Girl                                -0.934751     165000.0       0.0
# Ain't No Mountain High Enough          -0.326112     151667.0       0.0
# Brown Eyed Girl                        -0.934751     183307.0       0.0
# Here Comes The Sun - Remastered 2009   -0.021793     185733.0       0.0
# Fortunate Son                          -0.021793     140773.0       0.0
#
#                                                                artists  \
# name
# My Girl                                            ['The Temptations']
# Ain't No Mountain High Enough         ['Marvin Gaye', 'Tammi Terrell']
# Brown Eyed Girl                                       ['Van Morrison']
# Here Comes The Sun - Remastered 2009                   ['The Beatles']
# Fortunate Son                         ['Creedence Clearwater Revival']
#
#                                       danceability  loudness     tempo
# name
# My Girl                                  -0.737319 -1.699283 -0.569155
# Ain't No Mountain High Enough            -0.102100 -1.750395  0.290960
# Brown Eyed Girl                          -1.302734 -1.786792  0.987206
# Here Comes The Sun - Remastered 2009     -0.842026 -1.600933  0.263220
# Fortunate Son                            -0.262650 -0.451699  0.384973

# %%
KNN_top_tracks_proc = KNN_top_tracks_proc.drop(['name','artists'], axis=1)

# %%
KNN_top_tracks_proc.head()
# Out:
#                                                           id  popularity  \
# name
# My Girl                               745H5CctFr12Mo7cqa1BMH   -0.934751
# Ain't No Mountain High Enough         7tqhbajSfrz2F7E1Z75ASX   -0.326112
# Brown Eyed Girl                       3yrSvpt2l1xhsV9Em88Pul   -0.934751
# Here Comes The Sun - Remastered 2009  6dGnYIeXmHdcikdzNNDMm2   -0.021793
# Fortunate Son                         4BP3uh0hFLFRb5cjsgLqDh   -0.021793
#
#                                       duration_ms  explicit  danceability  \
# name
# My Girl                                  165000.0       0.0     -0.737319
# Ain't No Mountain High Enough            151667.0       0.0     -0.102100
# Brown Eyed Girl                          183307.0       0.0     -1.302734
# Here Comes The Sun - Remastered 2009     185733.0       0.0     -0.842026
# Fortunate Son                            140773.0       0.0     -0.262650
#
#                                       loudness     tempo
# name
# My Girl                              -1.699283 -0.569155
# Ain't No Mountain High Enough        -1.750395  0.290960
# Brown Eyed Girl                      -1.786792  0.987206
# Here Comes The Sun - Remastered 2009 -1.600933  0.263220
# Fortunate Son                        -0.451699  0.384973

# %%
KNN_top_tracks_proc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 782 entries, My Girl to Best Friend (feat. Doja Cat)
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            782 non-null    object
#  1   popularity    782 non-null    float64
#  2   duration_ms   782 non-null    float64
#  3   explicit      782 non-null    float64
#  4   danceability  782 non-null    float64
#  5   loudness      782 non-null    float64
#  6   tempo         782 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 48.9+ KB

# %%
KNN_top_tracks_proc.index = KNN_top_tracks_proc['id']

# %%
KNN_top_tracks_proc = KNN_top_tracks_proc.drop(['id'], axis=1)

# %%
KNN_top_tracks_proc.head()
# Out:
#                         popularity  duration_ms  explicit  danceability  \
# id
# 745H5CctFr12Mo7cqa1BMH   -0.934751     165000.0       0.0     -0.737319
# 7tqhbajSfrz2F7E1Z75ASX   -0.326112     151667.0       0.0     -0.102100
# 3yrSvpt2l1xhsV9Em88Pul   -0.934751     183307.0       0.0     -1.302734
# 6dGnYIeXmHdcikdzNNDMm2   -0.021793     185733.0       0.0     -0.842026
# 4BP3uh0hFLFRb5cjsgLqDh   -0.021793     140773.0       0.0     -0.262650
#
#                         loudness     tempo
# id
# 745H5CctFr12Mo7cqa1BMH -1.699283 -0.569155
# 7tqhbajSfrz2F7E1Z75ASX -1.750395  0.290960
# 3yrSvpt2l1xhsV9Em88Pul -1.786792  0.987206
# 6dGnYIeXmHdcikdzNNDMm2 -1.600933  0.263220
# 4BP3uh0hFLFRb5cjsgLqDh -0.451699  0.384973

# %%
model_knn = NearestNeighbors(metric='cosine', algorithm = 'brute', n_neighbors = 10)

# %%
from scipy.sparse import csr_matrix

# %%
mat_songs = csr_matrix(KNN_top_tracks_proc.values)

# %%
model_knn.fit(KNN_top_tracks_proc)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=10)

# %%
KNN_top_tracks_index.head()
# Out:
#                                                           id  \
# name
# My Girl                               745H5CctFr12Mo7cqa1BMH
# Ain't No Mountain High Enough         7tqhbajSfrz2F7E1Z75ASX
# Brown Eyed Girl                       3yrSvpt2l1xhsV9Em88Pul
# Here Comes The Sun - Remastered 2009  6dGnYIeXmHdcikdzNNDMm2
# Fortunate Son                         4BP3uh0hFLFRb5cjsgLqDh
#
#                                                                       name  \
# name
# My Girl                                                            My Girl
# Ain't No Mountain High Enough                Ain't No Mountain High Enough
# Brown Eyed Girl                                            Brown Eyed Girl
# Here Comes The Sun - Remastered 2009  Here Comes The Sun - Remastered 2009
# Fortunate Son                                                Fortunate Son
#
#                                       popularity  duration_ms  explicit  \
# name
# My Girl                                       80       165000         0
# Ain't No Mountain High Enough                 82       151667         0
# Brown Eyed Girl                               80       183307         0
# Here Comes The Sun - Remastered 2009          83       185733         0
# Fortunate Son                                 83       140773         0
#
#                                                                artists  \
# name
# My Girl                                            ['The Temptations']
# Ain't No Mountain High Enough         ['Marvin Gaye', 'Tammi Terrell']
# Brown Eyed Girl                                       ['Van Morrison']
# Here Comes The Sun - Remastered 2009                   ['The Beatles']
# Fortunate Son                         ['Creedence Clearwater Revival']
#
#                                      release_date  danceability  energy  key  \
# name
# My Girl                                1965-03-22         0.572   0.418    0
# Ain't No Mountain High Enough          1967-08-29         0.663   0.600    7
# Brown Eyed Girl                        1967-09-01         0.491   0.583    7
# Here Comes The Sun - Remastered 2009   1969-09-26         0.557   0.540    9
# Fortunate Son                          1969-11-02         0.640   0.663    0
#
#                                       loudness  mode  speechiness  \
# name
# My Girl                                -10.738     1       0.0349
# Ain't No Mountain High Enough          -10.870     1       0.0320
# Brown Eyed Girl                        -10.964     1       0.0376
# Here Comes The Sun - Remastered 2009   -10.484     1       0.0347
# Fortunate Son                           -7.516     1       0.0374
#
#                                       acousticness  instrumentalness  \
# name
# My Girl                                     0.6350           0.00000
# Ain't No Mountain High Enough               0.4300           0.00000
# Brown Eyed Girl                             0.1820           0.00000
# Here Comes The Sun - Remastered 2009        0.0339           0.00248
# Fortunate Son                               0.2010           0.00806
#
#                                       liveness  valence    tempo
# name
# My Girl                                 0.0961    0.694  104.566
# Ain't No Mountain High Enough           0.1840    0.800  129.991
# Brown Eyed Girl                         0.4070    0.907  150.572
# Here Comes The Sun - Remastered 2009    0.1790    0.394  129.171
# Fortunate Son                           0.1520    0.663  132.770

# %%
song = KNN_top_tracks_index['name'].loc[['Brown Eyed Girl']]

# %%
song = "Brown Eyed Girl"

# %%
idx = KNN_top_tracks_index['id'].loc[['Brown Eyed Girl']]

# %%
song
# Out:
# name
# Brown Eyed Girl    Brown Eyed Girl
# Name: name, dtype: object

# %%
idx
# Out:
# name
# Brown Eyed Girl    3yrSvpt2l1xhsV9Em88Pul
# Name: id, dtype: object

# %%
#distances, indices = model_knn.kneighbors(KNN_top_tracks_proc.loc[idx].to_numpy().reshape(1,-1), 11)
# Out:
# C:\Users\johnp\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   "X does not have valid feature names, but"

# %%
distances
# Out:
# array([[0.00000000e+00, 1.34002809e-11, 1.72392101e-11, 1.94123606e-11,
#         2.22200036e-11, 2.31004105e-11, 2.42313947e-11, 2.42811327e-11,
#         2.57444066e-11, 2.57629473e-11, 2.63998823e-11]])

# %%
indices[0]
# Out:
# array([  2, 590, 325,   5, 253,   6,   3, 294, 359, 399,  53], dtype=int64)

# %%
KNN_top_tracks_alpha[['name','artists']].loc[indices[0]].loc[KNN_top_tracks_alpha['name']!=song]
# Out:
#                                      name                       artists
# 590                    champagne problems              ['Taylor Swift']
# 325            i wanna be your girlfriend               ['girl in red']
# 5                               Your Song                ['Elton John']
# 253                idontwannabeyouanymore             ['Billie Eilish']
# 6                             Tiny Dancer                ['Elton John']
# 3    Here Comes The Sun - Remastered 2009               ['The Beatles']
# 294            we fell in love in october               ['girl in red']
# 359               Love Is Gone - Acoustic  ['SLANDER', 'Dylan Matthew']
# 399          you should see me in a crown             ['Billie Eilish']
# 53                                 Zombie           ['The Cranberries']

# %%
def recommender(idx,song, model_knn, KNN_top_tracks_alpha, KNN_top_tracks_proc):
    
    
    distances, indices = model_knn.kneighbors(KNN_top_tracks_proc.loc[idx].to_numpy().reshape(1,-1), 11)
    
    
    #KNN_top_tracks_alpha = KNN_top_tracks_alpha.reset_index(drop=True)
    #indices = indices.reset_index(drop=True)
    
    #indices.sort_index(axis=1) == KNN_top_tracks_alpha.sort_index().sort_index(axis=1)
    
    
    for i in indices:
        print(KNN_top_tracks_alpha[['name','artists']].loc[i].loc[KNN_top_tracks_alpha['name']!=song])

# %%
recommender(idx,song, model_knn, KNN_top_tracks_alpha, KNN_top_tracks_proc)
# Out:
#                                      name                       artists
# 590                    champagne problems              ['Taylor Swift']
# 325            i wanna be your girlfriend               ['girl in red']
# 5                               Your Song                ['Elton John']
# 253                idontwannabeyouanymore             ['Billie Eilish']
# 6                             Tiny Dancer                ['Elton John']
# 3    Here Comes The Sun - Remastered 2009               ['The Beatles']
# 294            we fell in love in october               ['girl in red']
# 359               Love Is Gone - Acoustic  ['SLANDER', 'Dylan Matthew']
# 399          you should see me in a crown             ['Billie Eilish']
# 53                                 Zombie           ['The Cranberries']
# C:\Users\johnp\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   "X does not have valid feature names, but"

# %%
KNN_top_tracks.head()
# Out:
#                                                           id  \
# name
# My Girl                               745H5CctFr12Mo7cqa1BMH
# Ain't No Mountain High Enough         7tqhbajSfrz2F7E1Z75ASX
# Brown Eyed Girl                       3yrSvpt2l1xhsV9Em88Pul
# Here Comes The Sun - Remastered 2009  6dGnYIeXmHdcikdzNNDMm2
# Fortunate Son                         4BP3uh0hFLFRb5cjsgLqDh
#
#                                                                       name  \
# name
# My Girl                                                            My Girl
# Ain't No Mountain High Enough                Ain't No Mountain High Enough
# Brown Eyed Girl                                            Brown Eyed Girl
# Here Comes The Sun - Remastered 2009  Here Comes The Sun - Remastered 2009
# Fortunate Son                                                Fortunate Son
#
#                                       popularity  duration_ms  explicit  \
# name
# My Girl                                       80       165000         0
# Ain't No Mountain High Enough                 82       151667         0
# Brown Eyed Girl                               80       183307         0
# Here Comes The Sun - Remastered 2009          83       185733         0
# Fortunate Son                                 83       140773         0
#
#                                                                artists  \
# name
# My Girl                                            ['The Temptations']
# Ain't No Mountain High Enough         ['Marvin Gaye', 'Tammi Terrell']
# Brown Eyed Girl                                       ['Van Morrison']
# Here Comes The Sun - Remastered 2009                   ['The Beatles']
# Fortunate Son                         ['Creedence Clearwater Revival']
#
#                                      release_date  danceability  energy  key  \
# name
# My Girl                                1965-03-22         0.572   0.418    0
# Ain't No Mountain High Enough          1967-08-29         0.663   0.600    7
# Brown Eyed Girl                        1967-09-01         0.491   0.583    7
# Here Comes The Sun - Remastered 2009   1969-09-26         0.557   0.540    9
# Fortunate Son                          1969-11-02         0.640   0.663    0
#
#                                       loudness  mode  speechiness  \
# name
# My Girl                                -10.738     1       0.0349
# Ain't No Mountain High Enough          -10.870     1       0.0320
# Brown Eyed Girl                        -10.964     1       0.0376
# Here Comes The Sun - Remastered 2009   -10.484     1       0.0347
# Fortunate Son                           -7.516     1       0.0374
#
#                                       acousticness  instrumentalness  \
# name
# My Girl                                     0.6350           0.00000
# Ain't No Mountain High Enough               0.4300           0.00000
# Brown Eyed Girl                             0.1820           0.00000
# Here Comes The Sun - Remastered 2009        0.0339           0.00248
# Fortunate Son                               0.2010           0.00806
#
#                                       liveness  valence    tempo
# name
# My Girl                                 0.0961    0.694  104.566
# Ain't No Mountain High Enough           0.1840    0.800  129.991
# Brown Eyed Girl                         0.4070    0.907  150.572
# Here Comes The Sun - Remastered 2009    0.1790    0.394  129.171
# Fortunate Son                           0.1520    0.663  132.770

# %%
KNN_top_tracks_alpha.head()
# Out:
#    Unnamed: 0                      id                                  name  \
# 0        4382  745H5CctFr12Mo7cqa1BMH                               My Girl
# 1        6382  7tqhbajSfrz2F7E1Z75ASX         Ain't No Mountain High Enough
# 2        6383  3yrSvpt2l1xhsV9Em88Pul                       Brown Eyed Girl
# 3        8372  6dGnYIeXmHdcikdzNNDMm2  Here Comes The Sun - Remastered 2009
# 4        8373  4BP3uh0hFLFRb5cjsgLqDh                         Fortunate Son
#
#    popularity  duration_ms  explicit                           artists  \
# 0          80       165000         0               ['The Temptations']
# 1          82       151667         0  ['Marvin Gaye', 'Tammi Terrell']
# 2          80       183307         0                  ['Van Morrison']
# 3          83       185733         0                   ['The Beatles']
# 4          83       140773         0  ['Creedence Clearwater Revival']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1965-03-22         0.572   0.418    0   -10.738     1       0.0349
# 1   1967-08-29         0.663   0.600    7   -10.870     1       0.0320
# 2   1967-09-01         0.491   0.583    7   -10.964     1       0.0376
# 3   1969-09-26         0.557   0.540    9   -10.484     1       0.0347
# 4   1969-11-02         0.640   0.663    0    -7.516     1       0.0374
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.6350           0.00000    0.0961    0.694  104.566
# 1        0.4300           0.00000    0.1840    0.800  129.991
# 2        0.1820           0.00000    0.4070    0.907  150.572
# 3        0.0339           0.00248    0.1790    0.394  129.171
# 4        0.2010           0.00806    0.1520    0.663  132.770

# %%
KNN_top_tracks_proc.head()
# Out:
#                         popularity  duration_ms  explicit  danceability  \
# id
# 745H5CctFr12Mo7cqa1BMH   -0.934751     165000.0       0.0     -0.737319
# 7tqhbajSfrz2F7E1Z75ASX   -0.326112     151667.0       0.0     -0.102100
# 3yrSvpt2l1xhsV9Em88Pul   -0.934751     183307.0       0.0     -1.302734
# 6dGnYIeXmHdcikdzNNDMm2   -0.021793     185733.0       0.0     -0.842026
# 4BP3uh0hFLFRb5cjsgLqDh   -0.021793     140773.0       0.0     -0.262650
#
#                         loudness     tempo
# id
# 745H5CctFr12Mo7cqa1BMH -1.699283 -0.569155
# 7tqhbajSfrz2F7E1Z75ASX -1.750395  0.290960
# 3yrSvpt2l1xhsV9Em88Pul -1.786792  0.987206
# 6dGnYIeXmHdcikdzNNDMm2 -1.600933  0.263220
# 4BP3uh0hFLFRb5cjsgLqDh -0.451699  0.384973

# %%
#def recommender(df, song, n_neighbor=10):
 #   model_knn = NearestNeighbors(metric='cosine', algorithm = 'brute', n_neighbors = 11)
 #   model_knn.fit(KNN_top_tracks_proc)
    
 #   song = KNN_top_tracks.to_numpy()
    
  #  distances, indices = model_knn.kneighbors(song, 11)
    
  #  result = KNN_top_tracks.iloc[indices.flatten()]
 #   result["Distance"] = distance.flatten()
    
  #  return result

# %%
#df_result = recommender(KNN_top_tracks, "My Girl")

# %%
#df_result.head()
