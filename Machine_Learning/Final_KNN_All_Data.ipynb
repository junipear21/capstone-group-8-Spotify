# %%
import pandas as pd
import numpy as np

from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler


from sklearn.metrics import silhouette_samples, silhouette_score
from pathlib import Path

# %%
# read in file
file1 = 'resources/tracks_df.csv'
tracks_df = pd.read_csv(file1)

# %%
tracks_df.head(5)
# Out:
#                        id                                            name  \
# 0  2G0GextMwZJLkNxcSZ7ZJ3                 (What A) Wonderful World - Mono
# 1  3oAWTk92mZBxKBOKf8mR5v                                Summertime Blues
# 2  2x6pbpjVGjiWCcH89IK8AX                       Breaking Up Is Hard to Do
# 3  47mA6f44zxLtdATOoY7GjN  Georgia on My Mind - Original Master Recording
# 4  0DICNd5XQ1og9UeYzxoNFV                 Baby (You've Got What It Takes)
#
#    popularity  duration_ms  explicit                               artists  \
# 0          67       128787         0                         ['Sam Cooke']
# 1          64       119360         0                     ['Eddie Cochran']
# 2          63       139200         0                       ['Neil Sedaka']
# 3          61       217415         0                       ['Ray Charles']
# 4          60       165760         0  ['Dinah Washington', 'Brook Benton']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1960-02-01         0.686   0.672   11    -5.523     1       0.0323
# 1   1960-05-01         0.714   0.886   11    -8.629     0       0.0554
# 2   1960-12-30         0.743   0.799    8    -5.466     0       0.0375
# 3   1960-09-01         0.138   0.399    7    -8.756     1       0.0311
# 4   1960-07-05         0.670   0.596    3    -9.347     1       0.0627
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.700          0.000000    0.1350    0.857  128.550
# 1         0.116          0.184000    0.1800    0.954  156.351
# 2         0.699          0.000000    0.0635    0.965  116.112
# 3         0.782          0.000004    0.1880    0.296  179.930
# 4         0.852          0.002030    0.6530    0.813  133.396

# %%
tracks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509268 entries, 0 to 509267
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                509268 non-null  object
#  1   name              509268 non-null  object
#  2   popularity        509268 non-null  int64
#  3   duration_ms       509268 non-null  int64
#  4   explicit          509268 non-null  int64
#  5   artists           509268 non-null  object
#  6   release_date      509268 non-null  object
#  7   danceability      509268 non-null  float64
#  8   energy            509268 non-null  float64
#  9   key               509268 non-null  int64
#  10  loudness          509268 non-null  float64
#  11  mode              509268 non-null  int64
#  12  speechiness       509268 non-null  float64
#  13  acousticness      509268 non-null  float64
#  14  instrumentalness  509268 non-null  float64
#  15  liveness          509268 non-null  float64
#  16  valence           509268 non-null  float64
#  17  tempo             509268 non-null  float64
# dtypes: float64(9), int64(5), object(4)
# memory usage: 69.9+ MB

# %%
tracks_df.shape[0]
# Out:
# 509268

# %%
tracks_df=tracks_df.drop_duplicates(subset=['name'])

# %%
tracks_df.shape[0]
# Out:
# 391661

# %%
tracks_df.head()
# Out:
#                        id                                            name  \
# 0  2G0GextMwZJLkNxcSZ7ZJ3                 (What A) Wonderful World - Mono
# 1  3oAWTk92mZBxKBOKf8mR5v                                Summertime Blues
# 2  2x6pbpjVGjiWCcH89IK8AX                       Breaking Up Is Hard to Do
# 3  47mA6f44zxLtdATOoY7GjN  Georgia on My Mind - Original Master Recording
# 4  0DICNd5XQ1og9UeYzxoNFV                 Baby (You've Got What It Takes)
#
#    popularity  duration_ms  explicit                               artists  \
# 0          67       128787         0                         ['Sam Cooke']
# 1          64       119360         0                     ['Eddie Cochran']
# 2          63       139200         0                       ['Neil Sedaka']
# 3          61       217415         0                       ['Ray Charles']
# 4          60       165760         0  ['Dinah Washington', 'Brook Benton']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1960-02-01         0.686   0.672   11    -5.523     1       0.0323
# 1   1960-05-01         0.714   0.886   11    -8.629     0       0.0554
# 2   1960-12-30         0.743   0.799    8    -5.466     0       0.0375
# 3   1960-09-01         0.138   0.399    7    -8.756     1       0.0311
# 4   1960-07-05         0.670   0.596    3    -9.347     1       0.0627
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.700          0.000000    0.1350    0.857  128.550
# 1         0.116          0.184000    0.1800    0.954  156.351
# 2         0.699          0.000000    0.0635    0.965  116.112
# 3         0.782          0.000004    0.1880    0.296  179.930
# 4         0.852          0.002030    0.6530    0.813  133.396

# %%
top_tracks_df = tracks_df[tracks_df["popularity"]>= 80]

# %%
top_tracks_df.head()
# Out:
#                           id                                  name  \
# 4382  745H5CctFr12Mo7cqa1BMH                               My Girl
# 6382  7tqhbajSfrz2F7E1Z75ASX         Ain't No Mountain High Enough
# 6383  3yrSvpt2l1xhsV9Em88Pul                       Brown Eyed Girl
# 8372  6dGnYIeXmHdcikdzNNDMm2  Here Comes The Sun - Remastered 2009
# 8373  4BP3uh0hFLFRb5cjsgLqDh                         Fortunate Son
#
#       popularity  duration_ms  explicit                           artists  \
# 4382          80       165000         0               ['The Temptations']
# 6382          82       151667         0  ['Marvin Gaye', 'Tammi Terrell']
# 6383          80       183307         0                  ['Van Morrison']
# 8372          83       185733         0                   ['The Beatles']
# 8373          83       140773         0  ['Creedence Clearwater Revival']
#
#      release_date  danceability  energy  key  loudness  mode  speechiness  \
# 4382   1965-03-22         0.572   0.418    0   -10.738     1       0.0349
# 6382   1967-08-29         0.663   0.600    7   -10.870     1       0.0320
# 6383   1967-09-01         0.491   0.583    7   -10.964     1       0.0376
# 8372   1969-09-26         0.557   0.540    9   -10.484     1       0.0347
# 8373   1969-11-02         0.640   0.663    0    -7.516     1       0.0374
#
#       acousticness  instrumentalness  liveness  valence    tempo
# 4382        0.6350           0.00000    0.0961    0.694  104.566
# 6382        0.4300           0.00000    0.1840    0.800  129.991
# 6383        0.1820           0.00000    0.4070    0.907  150.572
# 8372        0.0339           0.00248    0.1790    0.394  129.171
# 8373        0.2010           0.00806    0.1520    0.663  132.770

# %%
filepath = Path('Resources/KNN_top_tracks.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
top_tracks_df.to_csv(filepath)

# %%
file2 = 'resources/KNN_top_tracks.csv'
KNN_top_tracks = tracks_df

# %%
KNN_top_tracks.head()
# Out:
#                        id                                            name  \
# 0  2G0GextMwZJLkNxcSZ7ZJ3                 (What A) Wonderful World - Mono
# 1  3oAWTk92mZBxKBOKf8mR5v                                Summertime Blues
# 2  2x6pbpjVGjiWCcH89IK8AX                       Breaking Up Is Hard to Do
# 3  47mA6f44zxLtdATOoY7GjN  Georgia on My Mind - Original Master Recording
# 4  0DICNd5XQ1og9UeYzxoNFV                 Baby (You've Got What It Takes)
#
#    popularity  duration_ms  explicit                               artists  \
# 0          67       128787         0                         ['Sam Cooke']
# 1          64       119360         0                     ['Eddie Cochran']
# 2          63       139200         0                       ['Neil Sedaka']
# 3          61       217415         0                       ['Ray Charles']
# 4          60       165760         0  ['Dinah Washington', 'Brook Benton']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1960-02-01         0.686   0.672   11    -5.523     1       0.0323
# 1   1960-05-01         0.714   0.886   11    -8.629     0       0.0554
# 2   1960-12-30         0.743   0.799    8    -5.466     0       0.0375
# 3   1960-09-01         0.138   0.399    7    -8.756     1       0.0311
# 4   1960-07-05         0.670   0.596    3    -9.347     1       0.0627
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.700          0.000000    0.1350    0.857  128.550
# 1         0.116          0.184000    0.1800    0.954  156.351
# 2         0.699          0.000000    0.0635    0.965  116.112
# 3         0.782          0.000004    0.1880    0.296  179.930
# 4         0.852          0.002030    0.6530    0.813  133.396

# %%
KNN_top_tracks_alpha = pd.read_csv(file1)

# %%
KNN_top_tracks_alpha.head()
# Out:
#                        id                                            name  \
# 0  2G0GextMwZJLkNxcSZ7ZJ3                 (What A) Wonderful World - Mono
# 1  3oAWTk92mZBxKBOKf8mR5v                                Summertime Blues
# 2  2x6pbpjVGjiWCcH89IK8AX                       Breaking Up Is Hard to Do
# 3  47mA6f44zxLtdATOoY7GjN  Georgia on My Mind - Original Master Recording
# 4  0DICNd5XQ1og9UeYzxoNFV                 Baby (You've Got What It Takes)
#
#    popularity  duration_ms  explicit                               artists  \
# 0          67       128787         0                         ['Sam Cooke']
# 1          64       119360         0                     ['Eddie Cochran']
# 2          63       139200         0                       ['Neil Sedaka']
# 3          61       217415         0                       ['Ray Charles']
# 4          60       165760         0  ['Dinah Washington', 'Brook Benton']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1960-02-01         0.686   0.672   11    -5.523     1       0.0323
# 1   1960-05-01         0.714   0.886   11    -8.629     0       0.0554
# 2   1960-12-30         0.743   0.799    8    -5.466     0       0.0375
# 3   1960-09-01         0.138   0.399    7    -8.756     1       0.0311
# 4   1960-07-05         0.670   0.596    3    -9.347     1       0.0627
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.700          0.000000    0.1350    0.857  128.550
# 1         0.116          0.184000    0.1800    0.954  156.351
# 2         0.699          0.000000    0.0635    0.965  116.112
# 3         0.782          0.000004    0.1880    0.296  179.930
# 4         0.852          0.002030    0.6530    0.813  133.396

# %%
#KNN_top_tracks = KNN_top_tracks.drop(['Unnamed: 0'], axis=1)

# %%
KNN_top_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 391661 entries, 0 to 509266
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                391661 non-null  object
#  1   name              391661 non-null  object
#  2   popularity        391661 non-null  int64
#  3   duration_ms       391661 non-null  int64
#  4   explicit          391661 non-null  int64
#  5   artists           391661 non-null  object
#  6   release_date      391661 non-null  object
#  7   danceability      391661 non-null  float64
#  8   energy            391661 non-null  float64
#  9   key               391661 non-null  int64
#  10  loudness          391661 non-null  float64
#  11  mode              391661 non-null  int64
#  12  speechiness       391661 non-null  float64
#  13  acousticness      391661 non-null  float64
#  14  instrumentalness  391661 non-null  float64
#  15  liveness          391661 non-null  float64
#  16  valence           391661 non-null  float64
#  17  tempo             391661 non-null  float64
# dtypes: float64(9), int64(5), object(4)
# memory usage: 56.8+ MB

# %%
KNN_top_tracks.head()
# Out:
#                        id                                            name  \
# 0  2G0GextMwZJLkNxcSZ7ZJ3                 (What A) Wonderful World - Mono
# 1  3oAWTk92mZBxKBOKf8mR5v                                Summertime Blues
# 2  2x6pbpjVGjiWCcH89IK8AX                       Breaking Up Is Hard to Do
# 3  47mA6f44zxLtdATOoY7GjN  Georgia on My Mind - Original Master Recording
# 4  0DICNd5XQ1og9UeYzxoNFV                 Baby (You've Got What It Takes)
#
#    popularity  duration_ms  explicit                               artists  \
# 0          67       128787         0                         ['Sam Cooke']
# 1          64       119360         0                     ['Eddie Cochran']
# 2          63       139200         0                       ['Neil Sedaka']
# 3          61       217415         0                       ['Ray Charles']
# 4          60       165760         0  ['Dinah Washington', 'Brook Benton']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1960-02-01         0.686   0.672   11    -5.523     1       0.0323
# 1   1960-05-01         0.714   0.886   11    -8.629     0       0.0554
# 2   1960-12-30         0.743   0.799    8    -5.466     0       0.0375
# 3   1960-09-01         0.138   0.399    7    -8.756     1       0.0311
# 4   1960-07-05         0.670   0.596    3    -9.347     1       0.0627
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.700          0.000000    0.1350    0.857  128.550
# 1         0.116          0.184000    0.1800    0.954  156.351
# 2         0.699          0.000000    0.0635    0.965  116.112
# 3         0.782          0.000004    0.1880    0.296  179.930
# 4         0.852          0.002030    0.6530    0.813  133.396

# %%
KNN_top_tracks_index=KNN_top_tracks
KNN_top_tracks_index.index = KNN_top_tracks_index['name']

# %%
KNN_top_tracks_index.head()
# Out:
#                                                                     id  \
# name
# (What A) Wonderful World - Mono                 2G0GextMwZJLkNxcSZ7ZJ3
# Summertime Blues                                3oAWTk92mZBxKBOKf8mR5v
# Breaking Up Is Hard to Do                       2x6pbpjVGjiWCcH89IK8AX
# Georgia on My Mind - Original Master Recording  47mA6f44zxLtdATOoY7GjN
# Baby (You've Got What It Takes)                 0DICNd5XQ1og9UeYzxoNFV
#
#                                                                                           name  \
# name
# (What A) Wonderful World - Mono                                (What A) Wonderful World - Mono
# Summertime Blues                                                              Summertime Blues
# Breaking Up Is Hard to Do                                            Breaking Up Is Hard to Do
# Georgia on My Mind - Original Master Recording  Georgia on My Mind - Original Master Recording
# Baby (You've Got What It Takes)                                Baby (You've Got What It Takes)
#
#                                                 popularity  duration_ms  \
# name
# (What A) Wonderful World - Mono                         67       128787
# Summertime Blues                                        64       119360
# Breaking Up Is Hard to Do                               63       139200
# Georgia on My Mind - Original Master Recording          61       217415
# Baby (You've Got What It Takes)                         60       165760
#
#                                                 explicit  \
# name
# (What A) Wonderful World - Mono                        0
# Summertime Blues                                       0
# Breaking Up Is Hard to Do                              0
# Georgia on My Mind - Original Master Recording         0
# Baby (You've Got What It Takes)                        0
#
#                                                                              artists  \
# name
# (What A) Wonderful World - Mono                                        ['Sam Cooke']
# Summertime Blues                                                   ['Eddie Cochran']
# Breaking Up Is Hard to Do                                            ['Neil Sedaka']
# Georgia on My Mind - Original Master Recording                       ['Ray Charles']
# Baby (You've Got What It Takes)                 ['Dinah Washington', 'Brook Benton']
#
#                                                release_date  danceability  \
# name
# (What A) Wonderful World - Mono                  1960-02-01         0.686
# Summertime Blues                                 1960-05-01         0.714
# Breaking Up Is Hard to Do                        1960-12-30         0.743
# Georgia on My Mind - Original Master Recording   1960-09-01         0.138
# Baby (You've Got What It Takes)                  1960-07-05         0.670
#
#                                                 energy  key  loudness  mode  \
# name
# (What A) Wonderful World - Mono                  0.672   11    -5.523     1
# Summertime Blues                                 0.886   11    -8.629     0
# Breaking Up Is Hard to Do                        0.799    8    -5.466     0
# Georgia on My Mind - Original Master Recording   0.399    7    -8.756     1
# Baby (You've Got What It Takes)                  0.596    3    -9.347     1
#
#                                                 speechiness  acousticness  \
# name
# (What A) Wonderful World - Mono                      0.0323         0.700
# Summertime Blues                                     0.0554         0.116
# Breaking Up Is Hard to Do                            0.0375         0.699
# Georgia on My Mind - Original Master Recording       0.0311         0.782
# Baby (You've Got What It Takes)                      0.0627         0.852
#
#                                                 instrumentalness  liveness  \
# name
# (What A) Wonderful World - Mono                         0.000000    0.1350
# Summertime Blues                                        0.184000    0.1800
# Breaking Up Is Hard to Do                               0.000000    0.0635
# Georgia on My Mind - Original Master Recording          0.000004    0.1880
# Baby (You've Got What It Takes)                         0.002030    0.6530
#
#                                                 valence    tempo
# name
# (What A) Wonderful World - Mono                   0.857  128.550
# Summertime Blues                                  0.954  156.351
# Breaking Up Is Hard to Do                         0.965  116.112
# Georgia on My Mind - Original Master Recording    0.296  179.930
# Baby (You've Got What It Takes)                   0.813  133.396

# %%
KNN_top_tracks_index.drop(['name'], axis=1)
# Out:
#                                                                     id  \
# name
# (What A) Wonderful World - Mono                 2G0GextMwZJLkNxcSZ7ZJ3
# Summertime Blues                                3oAWTk92mZBxKBOKf8mR5v
# Breaking Up Is Hard to Do                       2x6pbpjVGjiWCcH89IK8AX
# Georgia on My Mind - Original Master Recording  47mA6f44zxLtdATOoY7GjN
# Baby (You've Got What It Takes)                 0DICNd5XQ1og9UeYzxoNFV
# ...                                                                ...
# John Brown's Song                               0SjsIzJkZfDU7wlcdklEFR
# 云与海                                             5rgu12WBIHQtvej2MdHSH0
# blind                                           0NuWgxEp51CutD2pJoF4OM
# What They'll Say About Us                       27Y1N4Q4U3EfDU5Ubw8ws2
# A Day At A Time                                 45XJsGpFTyzbzeWK8VzR8S
#
#                                                 popularity  duration_ms  \
# name
# (What A) Wonderful World - Mono                         67       128787
# Summertime Blues                                        64       119360
# Breaking Up Is Hard to Do                               63       139200
# Georgia on My Mind - Original Master Recording          61       217415
# Baby (You've Got What It Takes)                         60       165760
# ...                                                    ...          ...
# John Brown's Song                                       66       185250
# 云与海                                                     50       258267
# blind                                                   72       153293
# What They'll Say About Us                               70       187601
# A Day At A Time                                         58       142003
#
#                                                 explicit  \
# name
# (What A) Wonderful World - Mono                        0
# Summertime Blues                                       0
# Breaking Up Is Hard to Do                              0
# Georgia on My Mind - Original Master Recording         0
# Baby (You've Got What It Takes)                        0
# ...                                                  ...
# John Brown's Song                                      0
# 云与海                                                    0
# blind                                                  0
# What They'll Say About Us                              0
# A Day At A Time                                        0
#
#                                                                              artists  \
# name
# (What A) Wonderful World - Mono                                        ['Sam Cooke']
# Summertime Blues                                                   ['Eddie Cochran']
# Breaking Up Is Hard to Do                                            ['Neil Sedaka']
# Georgia on My Mind - Original Master Recording                       ['Ray Charles']
# Baby (You've Got What It Takes)                 ['Dinah Washington', 'Brook Benton']
# ...                                                                              ...
# John Brown's Song                                                 ['Gregory Oberle']
# 云与海                                                                      ['阿YueYue']
# blind                                                                 ['ROLE MODEL']
# What They'll Say About Us                                                ['FINNEAS']
# A Day At A Time                                      ['Gentle Bones', 'Clara Benin']
#
#                                                release_date  danceability  \
# name
# (What A) Wonderful World - Mono                  1960-02-01         0.686
# Summertime Blues                                 1960-05-01         0.714
# Breaking Up Is Hard to Do                        1960-12-30         0.743
# Georgia on My Mind - Original Master Recording   1960-09-01         0.138
# Baby (You've Got What It Takes)                  1960-07-05         0.670
# ...                                                     ...           ...
# John Brown's Song                                2020-03-20         0.562
# 云与海                                              2020-09-26         0.560
# blind                                            2020-10-21         0.765
# What They'll Say About Us                        2020-09-02         0.535
# A Day At A Time                                  2021-03-05         0.696
#
#                                                 energy  key  loudness  mode  \
# name
# (What A) Wonderful World - Mono                 0.6720   11    -5.523     1
# Summertime Blues                                0.8860   11    -8.629     0
# Breaking Up Is Hard to Do                       0.7990    8    -5.466     0
# Georgia on My Mind - Original Master Recording  0.3990    7    -8.756     1
# Baby (You've Got What It Takes)                 0.5960    3    -9.347     1
# ...                                                ...  ...       ...   ...
# John Brown's Song                               0.0331    1   -25.551     1
# 云与海                                             0.5180    0    -7.471     0
# blind                                           0.6630    0    -5.223     1
# What They'll Say About Us                       0.3140    7   -12.823     0
# A Day At A Time                                 0.6150   10    -6.212     1
#
#                                                 speechiness  acousticness  \
# name
# (What A) Wonderful World - Mono                      0.0323         0.700
# Summertime Blues                                     0.0554         0.116
# Breaking Up Is Hard to Do                            0.0375         0.699
# Georgia on My Mind - Original Master Recording       0.0311         0.782
# Baby (You've Got What It Takes)                      0.0627         0.852
# ...                                                     ...           ...
# John Brown's Song                                    0.1030         0.996
# 云与海                                                  0.0292         0.785
# blind                                                0.0652         0.141
# What They'll Say About Us                            0.0408         0.895
# A Day At A Time                                      0.0345         0.206
#
#                                                 instrumentalness  liveness  \
# name
# (What A) Wonderful World - Mono                         0.000000    0.1350
# Summertime Blues                                        0.184000    0.1800
# Breaking Up Is Hard to Do                               0.000000    0.0635
# Georgia on My Mind - Original Master Recording          0.000004    0.1880
# Baby (You've Got What It Takes)                         0.002030    0.6530
# ...                                                          ...       ...
# John Brown's Song                                       0.961000    0.1110
# 云与海                                                     0.000000    0.0648
# blind                                                   0.000297    0.0924
# What They'll Say About Us                               0.000150    0.0874
# A Day At A Time                                         0.000003    0.3050
#
#                                                 valence    tempo
# name
# (What A) Wonderful World - Mono                  0.8570  128.550
# Summertime Blues                                 0.9540  156.351
# Breaking Up Is Hard to Do                        0.9650  116.112
# Georgia on My Mind - Original Master Recording   0.2960  179.930
# Baby (You've Got What It Takes)                  0.8130  133.396
# ...                                                 ...      ...
# John Brown's Song                                0.3860   63.696
# 云与海                                              0.2110  131.896
# blind                                            0.6860  150.091
# What They'll Say About Us                        0.0663  145.095
# A Day At A Time                                  0.4380   90.029
#
# [391661 rows x 17 columns]

# %%
#tracks_index_df = tracks_df

# %%
#tracks_index_df.head()

# %%
#tracks_df2 = tracks_df
#top_tracks_df2 = tracks_df2

# %%
#tracks_df2.head()

# %%
#tracks_df.index = tracks_df['id']

# %%
#tracks_df = tracks_df.drop(['id'], axis=1)

# %%
#tracks_df.head()

# %%
#top_tracks_df = tracks_df

# %%
#top_tracks_df.head()

# %%
KNN_top_tracks_proc=KNN_top_tracks.drop(['release_date'], axis=1)
#.drop(['energy','key','mode','speechiness','acousticness','instrumentalness','liveness', 'valence', 'release_date'], axis=1)

# %%
KNN_top_tracks_proc
# Out:
#                                                                     id  \
# name
# (What A) Wonderful World - Mono                 2G0GextMwZJLkNxcSZ7ZJ3
# Summertime Blues                                3oAWTk92mZBxKBOKf8mR5v
# Breaking Up Is Hard to Do                       2x6pbpjVGjiWCcH89IK8AX
# Georgia on My Mind - Original Master Recording  47mA6f44zxLtdATOoY7GjN
# Baby (You've Got What It Takes)                 0DICNd5XQ1og9UeYzxoNFV
# ...                                                                ...
# John Brown's Song                               0SjsIzJkZfDU7wlcdklEFR
# 云与海                                             5rgu12WBIHQtvej2MdHSH0
# blind                                           0NuWgxEp51CutD2pJoF4OM
# What They'll Say About Us                       27Y1N4Q4U3EfDU5Ubw8ws2
# A Day At A Time                                 45XJsGpFTyzbzeWK8VzR8S
#
#                                                                                           name  \
# name
# (What A) Wonderful World - Mono                                (What A) Wonderful World - Mono
# Summertime Blues                                                              Summertime Blues
# Breaking Up Is Hard to Do                                            Breaking Up Is Hard to Do
# Georgia on My Mind - Original Master Recording  Georgia on My Mind - Original Master Recording
# Baby (You've Got What It Takes)                                Baby (You've Got What It Takes)
# ...                                                                                        ...
# John Brown's Song                                                            John Brown's Song
# 云与海                                                                                        云与海
# blind                                                                                    blind
# What They'll Say About Us                                            What They'll Say About Us
# A Day At A Time                                                                A Day At A Time
#
#                                                 popularity  duration_ms  \
# name
# (What A) Wonderful World - Mono                         67       128787
# Summertime Blues                                        64       119360
# Breaking Up Is Hard to Do                               63       139200
# Georgia on My Mind - Original Master Recording          61       217415
# Baby (You've Got What It Takes)                         60       165760
# ...                                                    ...          ...
# John Brown's Song                                       66       185250
# 云与海                                                     50       258267
# blind                                                   72       153293
# What They'll Say About Us                               70       187601
# A Day At A Time                                         58       142003
#
#                                                 explicit  \
# name
# (What A) Wonderful World - Mono                        0
# Summertime Blues                                       0
# Breaking Up Is Hard to Do                              0
# Georgia on My Mind - Original Master Recording         0
# Baby (You've Got What It Takes)                        0
# ...                                                  ...
# John Brown's Song                                      0
# 云与海                                                    0
# blind                                                  0
# What They'll Say About Us                              0
# A Day At A Time                                        0
#
#                                                                              artists  \
# name
# (What A) Wonderful World - Mono                                        ['Sam Cooke']
# Summertime Blues                                                   ['Eddie Cochran']
# Breaking Up Is Hard to Do                                            ['Neil Sedaka']
# Georgia on My Mind - Original Master Recording                       ['Ray Charles']
# Baby (You've Got What It Takes)                 ['Dinah Washington', 'Brook Benton']
# ...                                                                              ...
# John Brown's Song                                                 ['Gregory Oberle']
# 云与海                                                                      ['阿YueYue']
# blind                                                                 ['ROLE MODEL']
# What They'll Say About Us                                                ['FINNEAS']
# A Day At A Time                                      ['Gentle Bones', 'Clara Benin']
#
#                                                 danceability  energy  key  \
# name
# (What A) Wonderful World - Mono                        0.686  0.6720   11
# Summertime Blues                                       0.714  0.8860   11
# Breaking Up Is Hard to Do                              0.743  0.7990    8
# Georgia on My Mind - Original Master Recording         0.138  0.3990    7
# Baby (You've Got What It Takes)                        0.670  0.5960    3
# ...                                                      ...     ...  ...
# John Brown's Song                                      0.562  0.0331    1
# 云与海                                                    0.560  0.5180    0
# blind                                                  0.765  0.6630    0
# What They'll Say About Us                              0.535  0.3140    7
# A Day At A Time                                        0.696  0.6150   10
#
#                                                 loudness  mode  speechiness  \
# name
# (What A) Wonderful World - Mono                   -5.523     1       0.0323
# Summertime Blues                                  -8.629     0       0.0554
# Breaking Up Is Hard to Do                         -5.466     0       0.0375
# Georgia on My Mind - Original Master Recording    -8.756     1       0.0311
# Baby (You've Got What It Takes)                   -9.347     1       0.0627
# ...                                                  ...   ...          ...
# John Brown's Song                                -25.551     1       0.1030
# 云与海                                               -7.471     0       0.0292
# blind                                             -5.223     1       0.0652
# What They'll Say About Us                        -12.823     0       0.0408
# A Day At A Time                                   -6.212     1       0.0345
#
#                                                 acousticness  \
# name
# (What A) Wonderful World - Mono                        0.700
# Summertime Blues                                       0.116
# Breaking Up Is Hard to Do                              0.699
# Georgia on My Mind - Original Master Recording         0.782
# Baby (You've Got What It Takes)                        0.852
# ...                                                      ...
# John Brown's Song                                      0.996
# 云与海                                                    0.785
# blind                                                  0.141
# What They'll Say About Us                              0.895
# A Day At A Time                                        0.206
#
#                                                 instrumentalness  liveness  \
# name
# (What A) Wonderful World - Mono                         0.000000    0.1350
# Summertime Blues                                        0.184000    0.1800
# Breaking Up Is Hard to Do                               0.000000    0.0635
# Georgia on My Mind - Original Master Recording          0.000004    0.1880
# Baby (You've Got What It Takes)                         0.002030    0.6530
# ...                                                          ...       ...
# John Brown's Song                                       0.961000    0.1110
# 云与海                                                     0.000000    0.0648
# blind                                                   0.000297    0.0924
# What They'll Say About Us                               0.000150    0.0874
# A Day At A Time                                         0.000003    0.3050
#
#                                                 valence    tempo
# name
# (What A) Wonderful World - Mono                  0.8570  128.550
# Summertime Blues                                 0.9540  156.351
# Breaking Up Is Hard to Do                        0.9650  116.112
# Georgia on My Mind - Original Master Recording   0.2960  179.930
# Baby (You've Got What It Takes)                  0.8130  133.396
# ...                                                 ...      ...
# John Brown's Song                                0.3860   63.696
# 云与海                                              0.2110  131.896
# blind                                            0.6860  150.091
# What They'll Say About Us                        0.0663  145.095
# A Day At A Time                                  0.4380   90.029
#
# [391661 rows x 17 columns]

# %%
KNN_top_tracks_proc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391661 entries, (What A) Wonderful World - Mono to A Day At A Time
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                391661 non-null  object
#  1   name              391661 non-null  object
#  2   popularity        391661 non-null  int64
#  3   duration_ms       391661 non-null  int64
#  4   explicit          391661 non-null  int64
#  5   artists           391661 non-null  object
#  6   danceability      391661 non-null  float64
#  7   energy            391661 non-null  float64
#  8   key               391661 non-null  int64
#  9   loudness          391661 non-null  float64
#  10  mode              391661 non-null  int64
#  11  speechiness       391661 non-null  float64
#  12  acousticness      391661 non-null  float64
#  13  instrumentalness  391661 non-null  float64
#  14  liveness          391661 non-null  float64
#  15  valence           391661 non-null  float64
#  16  tempo             391661 non-null  float64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 53.8+ MB

# %%
#proctop_tracks_df = top_tracks_df.drop(['name','artists'], axis=1)

# %%
#top_tracks_df.info()

# %%
#top_tracks_df.head()

# %%
KNN_top_tracks_proc["popularity"] = KNN_top_tracks_proc["popularity"].astype(float)
KNN_top_tracks_proc["duration_ms"] = KNN_top_tracks_proc["duration_ms"].astype(float)
KNN_top_tracks_proc["explicit"] = KNN_top_tracks_proc["explicit"].astype(float)
KNN_top_tracks_proc["energy"] = KNN_top_tracks_proc["explicit"].astype(float)
KNN_top_tracks_proc["key"] = KNN_top_tracks_proc["explicit"].astype(float)
KNN_top_tracks_proc["mode"] = KNN_top_tracks_proc["explicit"].astype(float)
KNN_top_tracks_proc["speechiness"] = KNN_top_tracks_proc["explicit"].astype(float)
KNN_top_tracks_proc["acousticness"] = KNN_top_tracks_proc["explicit"].astype(float)
KNN_top_tracks_proc["instrumentalness"] = KNN_top_tracks_proc["explicit"].astype(float)
KNN_top_tracks_proc["valence"] = KNN_top_tracks_proc["explicit"].astype(float)

#'energy','key','mode','speechiness','acousticness','instrumentalness','liveness', 'valence'

# %%
KNN_top_tracks_proc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391661 entries, (What A) Wonderful World - Mono to A Day At A Time
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                391661 non-null  object
#  1   name              391661 non-null  object
#  2   popularity        391661 non-null  float64
#  3   duration_ms       391661 non-null  float64
#  4   explicit          391661 non-null  float64
#  5   artists           391661 non-null  object
#  6   danceability      391661 non-null  float64
#  7   energy            391661 non-null  float64
#  8   key               391661 non-null  float64
#  9   loudness          391661 non-null  float64
#  10  mode              391661 non-null  float64
#  11  speechiness       391661 non-null  float64
#  12  acousticness      391661 non-null  float64
#  13  instrumentalness  391661 non-null  float64
#  14  liveness          391661 non-null  float64
#  15  valence           391661 non-null  float64
#  16  tempo             391661 non-null  float64
# dtypes: float64(14), object(3)
# memory usage: 53.8+ MB

# %%
KNN_top_tracks_proc.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
KNN_top_tracks_proc.head()
# Out:
#                                                                     id  \
# name
# (What A) Wonderful World - Mono                 2G0GextMwZJLkNxcSZ7ZJ3
# Summertime Blues                                3oAWTk92mZBxKBOKf8mR5v
# Breaking Up Is Hard to Do                       2x6pbpjVGjiWCcH89IK8AX
# Georgia on My Mind - Original Master Recording  47mA6f44zxLtdATOoY7GjN
# Baby (You've Got What It Takes)                 0DICNd5XQ1og9UeYzxoNFV
#
#                                                                                           name  \
# name
# (What A) Wonderful World - Mono                                (What A) Wonderful World - Mono
# Summertime Blues                                                              Summertime Blues
# Breaking Up Is Hard to Do                                            Breaking Up Is Hard to Do
# Georgia on My Mind - Original Master Recording  Georgia on My Mind - Original Master Recording
# Baby (You've Got What It Takes)                                Baby (You've Got What It Takes)
#
#                                                 popularity  duration_ms  \
# name
# (What A) Wonderful World - Mono                       67.0     128787.0
# Summertime Blues                                      64.0     119360.0
# Breaking Up Is Hard to Do                             63.0     139200.0
# Georgia on My Mind - Original Master Recording        61.0     217415.0
# Baby (You've Got What It Takes)                       60.0     165760.0
#
#                                                 explicit  \
# name
# (What A) Wonderful World - Mono                      0.0
# Summertime Blues                                     0.0
# Breaking Up Is Hard to Do                            0.0
# Georgia on My Mind - Original Master Recording       0.0
# Baby (You've Got What It Takes)                      0.0
#
#                                                                              artists  \
# name
# (What A) Wonderful World - Mono                                        ['Sam Cooke']
# Summertime Blues                                                   ['Eddie Cochran']
# Breaking Up Is Hard to Do                                            ['Neil Sedaka']
# Georgia on My Mind - Original Master Recording                       ['Ray Charles']
# Baby (You've Got What It Takes)                 ['Dinah Washington', 'Brook Benton']
#
#                                                 danceability  energy  key  \
# name
# (What A) Wonderful World - Mono                        0.686     0.0  0.0
# Summertime Blues                                       0.714     0.0  0.0
# Breaking Up Is Hard to Do                              0.743     0.0  0.0
# Georgia on My Mind - Original Master Recording         0.138     0.0  0.0
# Baby (You've Got What It Takes)                        0.670     0.0  0.0
#
#                                                 loudness  mode  speechiness  \
# name
# (What A) Wonderful World - Mono                   -5.523   0.0          0.0
# Summertime Blues                                  -8.629   0.0          0.0
# Breaking Up Is Hard to Do                         -5.466   0.0          0.0
# Georgia on My Mind - Original Master Recording    -8.756   0.0          0.0
# Baby (You've Got What It Takes)                   -9.347   0.0          0.0
#
#                                                 acousticness  \
# name
# (What A) Wonderful World - Mono                          0.0
# Summertime Blues                                         0.0
# Breaking Up Is Hard to Do                                0.0
# Georgia on My Mind - Original Master Recording           0.0
# Baby (You've Got What It Takes)                          0.0
#
#                                                 instrumentalness  liveness  \
# name
# (What A) Wonderful World - Mono                              0.0    0.1350
# Summertime Blues                                             0.0    0.1800
# Breaking Up Is Hard to Do                                    0.0    0.0635
# Georgia on My Mind - Original Master Recording               0.0    0.1880
# Baby (You've Got What It Takes)                              0.0    0.6530
#
#                                                 valence    tempo
# name
# (What A) Wonderful World - Mono                     0.0  128.550
# Summertime Blues                                    0.0  156.351
# Breaking Up Is Hard to Do                           0.0  116.112
# Georgia on My Mind - Original Master Recording      0.0  179.930
# Baby (You've Got What It Takes)                     0.0  133.396

# %%
KNN_top_tracks_proc[['popularity', 'danceability', 'loudness', 'tempo', 'energy', 'key', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'instrumentalness', 'valence']]= StandardScaler().fit_transform(KNN_top_tracks_proc
    [['popularity', 'danceability', 'loudness', 'tempo', 'energy', 'key', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'instrumentalness', 'valence']])

#'energy','key','mode','speechiness','acousticness','instrumentalness','liveness', 'valence'

# %%
KNN_top_tracks_proc.head()
# Out:
#                                                                     id  \
# name
# (What A) Wonderful World - Mono                 2G0GextMwZJLkNxcSZ7ZJ3
# Summertime Blues                                3oAWTk92mZBxKBOKf8mR5v
# Breaking Up Is Hard to Do                       2x6pbpjVGjiWCcH89IK8AX
# Georgia on My Mind - Original Master Recording  47mA6f44zxLtdATOoY7GjN
# Baby (You've Got What It Takes)                 0DICNd5XQ1og9UeYzxoNFV
#
#                                                                                           name  \
# name
# (What A) Wonderful World - Mono                                (What A) Wonderful World - Mono
# Summertime Blues                                                              Summertime Blues
# Breaking Up Is Hard to Do                                            Breaking Up Is Hard to Do
# Georgia on My Mind - Original Master Recording  Georgia on My Mind - Original Master Recording
# Baby (You've Got What It Takes)                                Baby (You've Got What It Takes)
#
#                                                 popularity  duration_ms  \
# name
# (What A) Wonderful World - Mono                   2.154349     128787.0
# Summertime Blues                                  1.977253     119360.0
# Breaking Up Is Hard to Do                         1.918221     139200.0
# Georgia on My Mind - Original Master Recording    1.800158     217415.0
# Baby (You've Got What It Takes)                   1.741126     165760.0
#
#                                                 explicit  \
# name
# (What A) Wonderful World - Mono                      0.0
# Summertime Blues                                     0.0
# Breaking Up Is Hard to Do                            0.0
# Georgia on My Mind - Original Master Recording       0.0
# Baby (You've Got What It Takes)                      0.0
#
#                                                                              artists  \
# name
# (What A) Wonderful World - Mono                                        ['Sam Cooke']
# Summertime Blues                                                   ['Eddie Cochran']
# Breaking Up Is Hard to Do                                            ['Neil Sedaka']
# Georgia on My Mind - Original Master Recording                       ['Ray Charles']
# Baby (You've Got What It Takes)                 ['Dinah Washington', 'Brook Benton']
#
#                                                 danceability    energy  \
# name
# (What A) Wonderful World - Mono                     0.689451 -0.234264
# Summertime Blues                                    0.860380 -0.234264
# Breaking Up Is Hard to Do                           1.037413 -0.234264
# Georgia on My Mind - Original Master Recording     -2.655868 -0.234264
# Baby (You've Got What It Takes)                     0.591778 -0.234264
#
#                                                      key  loudness      mode  \
# name
# (What A) Wonderful World - Mono                -0.234264  0.879065 -0.234264
# Summertime Blues                               -0.234264  0.227086 -0.234264
# Breaking Up Is Hard to Do                      -0.234264  0.891030 -0.234264
# Georgia on My Mind - Original Master Recording -0.234264  0.200428 -0.234264
# Baby (You've Got What It Takes)                -0.234264  0.076371 -0.234264
#
#                                                 speechiness  acousticness  \
# name
# (What A) Wonderful World - Mono                   -0.234264     -0.234264
# Summertime Blues                                  -0.234264     -0.234264
# Breaking Up Is Hard to Do                         -0.234264     -0.234264
# Georgia on My Mind - Original Master Recording    -0.234264     -0.234264
# Baby (You've Got What It Takes)                   -0.234264     -0.234264
#
#                                                 instrumentalness  liveness  \
# name
# (What A) Wonderful World - Mono                        -0.234264    0.1350
# Summertime Blues                                       -0.234264    0.1800
# Breaking Up Is Hard to Do                              -0.234264    0.0635
# Georgia on My Mind - Original Master Recording         -0.234264    0.1880
# Baby (You've Got What It Takes)                        -0.234264    0.6530
#
#                                                  valence     tempo
# name
# (What A) Wonderful World - Mono                -0.234264  0.306697
# Summertime Blues                               -0.234264  1.253152
# Breaking Up Is Hard to Do                      -0.234264 -0.116741
# Georgia on My Mind - Original Master Recording -0.234264  2.055873
# Baby (You've Got What It Takes)                -0.234264  0.471674

# %%
KNN_top_tracks_proc = KNN_top_tracks_proc.drop(['name','artists'], axis=1)

# %%
KNN_top_tracks_proc.head()
# Out:
#                                                                     id  \
# name
# (What A) Wonderful World - Mono                 2G0GextMwZJLkNxcSZ7ZJ3
# Summertime Blues                                3oAWTk92mZBxKBOKf8mR5v
# Breaking Up Is Hard to Do                       2x6pbpjVGjiWCcH89IK8AX
# Georgia on My Mind - Original Master Recording  47mA6f44zxLtdATOoY7GjN
# Baby (You've Got What It Takes)                 0DICNd5XQ1og9UeYzxoNFV
#
#                                                 popularity  duration_ms  \
# name
# (What A) Wonderful World - Mono                   2.154349     128787.0
# Summertime Blues                                  1.977253     119360.0
# Breaking Up Is Hard to Do                         1.918221     139200.0
# Georgia on My Mind - Original Master Recording    1.800158     217415.0
# Baby (You've Got What It Takes)                   1.741126     165760.0
#
#                                                 explicit  danceability  \
# name
# (What A) Wonderful World - Mono                      0.0      0.689451
# Summertime Blues                                     0.0      0.860380
# Breaking Up Is Hard to Do                            0.0      1.037413
# Georgia on My Mind - Original Master Recording       0.0     -2.655868
# Baby (You've Got What It Takes)                      0.0      0.591778
#
#                                                   energy       key  loudness  \
# name
# (What A) Wonderful World - Mono                -0.234264 -0.234264  0.879065
# Summertime Blues                               -0.234264 -0.234264  0.227086
# Breaking Up Is Hard to Do                      -0.234264 -0.234264  0.891030
# Georgia on My Mind - Original Master Recording -0.234264 -0.234264  0.200428
# Baby (You've Got What It Takes)                -0.234264 -0.234264  0.076371
#
#                                                     mode  speechiness  \
# name
# (What A) Wonderful World - Mono                -0.234264    -0.234264
# Summertime Blues                               -0.234264    -0.234264
# Breaking Up Is Hard to Do                      -0.234264    -0.234264
# Georgia on My Mind - Original Master Recording -0.234264    -0.234264
# Baby (You've Got What It Takes)                -0.234264    -0.234264
#
#                                                 acousticness  \
# name
# (What A) Wonderful World - Mono                    -0.234264
# Summertime Blues                                   -0.234264
# Breaking Up Is Hard to Do                          -0.234264
# Georgia on My Mind - Original Master Recording     -0.234264
# Baby (You've Got What It Takes)                    -0.234264
#
#                                                 instrumentalness  liveness  \
# name
# (What A) Wonderful World - Mono                        -0.234264    0.1350
# Summertime Blues                                       -0.234264    0.1800
# Breaking Up Is Hard to Do                              -0.234264    0.0635
# Georgia on My Mind - Original Master Recording         -0.234264    0.1880
# Baby (You've Got What It Takes)                        -0.234264    0.6530
#
#                                                  valence     tempo
# name
# (What A) Wonderful World - Mono                -0.234264  0.306697
# Summertime Blues                               -0.234264  1.253152
# Breaking Up Is Hard to Do                      -0.234264 -0.116741
# Georgia on My Mind - Original Master Recording -0.234264  2.055873
# Baby (You've Got What It Takes)                -0.234264  0.471674

# %%
KNN_top_tracks_proc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391661 entries, (What A) Wonderful World - Mono to A Day At A Time
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                391661 non-null  object
#  1   popularity        391661 non-null  float64
#  2   duration_ms       391661 non-null  float64
#  3   explicit          391661 non-null  float64
#  4   danceability      391661 non-null  float64
#  5   energy            391661 non-null  float64
#  6   key               391661 non-null  float64
#  7   loudness          391661 non-null  float64
#  8   mode              391661 non-null  float64
#  9   speechiness       391661 non-null  float64
#  10  acousticness      391661 non-null  float64
#  11  instrumentalness  391661 non-null  float64
#  12  liveness          391661 non-null  float64
#  13  valence           391661 non-null  float64
#  14  tempo             391661 non-null  float64
# dtypes: float64(14), object(1)
# memory usage: 47.8+ MB

# %%
#KNN_top_tracks_proc.index = KNN_top_tracks_proc['id']

# %%
KNN_top_tracks_proc = KNN_top_tracks_proc.drop(['id'], axis=1)

# %%
KNN_top_tracks_proc.head()
# Out:
#                                                 popularity  duration_ms  \
# name
# (What A) Wonderful World - Mono                   2.154349     128787.0
# Summertime Blues                                  1.977253     119360.0
# Breaking Up Is Hard to Do                         1.918221     139200.0
# Georgia on My Mind - Original Master Recording    1.800158     217415.0
# Baby (You've Got What It Takes)                   1.741126     165760.0
#
#                                                 explicit  danceability  \
# name
# (What A) Wonderful World - Mono                      0.0      0.689451
# Summertime Blues                                     0.0      0.860380
# Breaking Up Is Hard to Do                            0.0      1.037413
# Georgia on My Mind - Original Master Recording       0.0     -2.655868
# Baby (You've Got What It Takes)                      0.0      0.591778
#
#                                                   energy       key  loudness  \
# name
# (What A) Wonderful World - Mono                -0.234264 -0.234264  0.879065
# Summertime Blues                               -0.234264 -0.234264  0.227086
# Breaking Up Is Hard to Do                      -0.234264 -0.234264  0.891030
# Georgia on My Mind - Original Master Recording -0.234264 -0.234264  0.200428
# Baby (You've Got What It Takes)                -0.234264 -0.234264  0.076371
#
#                                                     mode  speechiness  \
# name
# (What A) Wonderful World - Mono                -0.234264    -0.234264
# Summertime Blues                               -0.234264    -0.234264
# Breaking Up Is Hard to Do                      -0.234264    -0.234264
# Georgia on My Mind - Original Master Recording -0.234264    -0.234264
# Baby (You've Got What It Takes)                -0.234264    -0.234264
#
#                                                 acousticness  \
# name
# (What A) Wonderful World - Mono                    -0.234264
# Summertime Blues                                   -0.234264
# Breaking Up Is Hard to Do                          -0.234264
# Georgia on My Mind - Original Master Recording     -0.234264
# Baby (You've Got What It Takes)                    -0.234264
#
#                                                 instrumentalness  liveness  \
# name
# (What A) Wonderful World - Mono                        -0.234264    0.1350
# Summertime Blues                                       -0.234264    0.1800
# Breaking Up Is Hard to Do                              -0.234264    0.0635
# Georgia on My Mind - Original Master Recording         -0.234264    0.1880
# Baby (You've Got What It Takes)                        -0.234264    0.6530
#
#                                                  valence     tempo
# name
# (What A) Wonderful World - Mono                -0.234264  0.306697
# Summertime Blues                               -0.234264  1.253152
# Breaking Up Is Hard to Do                      -0.234264 -0.116741
# Georgia on My Mind - Original Master Recording -0.234264  2.055873
# Baby (You've Got What It Takes)                -0.234264  0.471674

# %%
model_knn = NearestNeighbors(metric='cosine', algorithm = 'brute', n_neighbors = 10)

# %%
model_knn.fit(KNN_top_tracks_proc)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=10)

# %%
KNN_top_tracks_index.tail()
# Out:
#                                                id                       name  \
# name
# John Brown's Song          0SjsIzJkZfDU7wlcdklEFR          John Brown's Song
# 云与海                        5rgu12WBIHQtvej2MdHSH0                        云与海
# blind                      0NuWgxEp51CutD2pJoF4OM                      blind
# What They'll Say About Us  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us
# A Day At A Time            45XJsGpFTyzbzeWK8VzR8S            A Day At A Time
#
#                            popularity  duration_ms  explicit  \
# name
# John Brown's Song                  66       185250         0
# 云与海                                50       258267         0
# blind                              72       153293         0
# What They'll Say About Us          70       187601         0
# A Day At A Time                    58       142003         0
#
#                                                    artists release_date  \
# name
# John Brown's Song                       ['Gregory Oberle']   2020-03-20
# 云与海                                            ['阿YueYue']   2020-09-26
# blind                                       ['ROLE MODEL']   2020-10-21
# What They'll Say About Us                      ['FINNEAS']   2020-09-02
# A Day At A Time            ['Gentle Bones', 'Clara Benin']   2021-03-05
#
#                            danceability  energy  key  loudness  mode  \
# name
# John Brown's Song                 0.562  0.0331    1   -25.551     1
# 云与海                               0.560  0.5180    0    -7.471     0
# blind                             0.765  0.6630    0    -5.223     1
# What They'll Say About Us         0.535  0.3140    7   -12.823     0
# A Day At A Time                   0.696  0.6150   10    -6.212     1
#
#                            speechiness  acousticness  instrumentalness  \
# name
# John Brown's Song               0.1030         0.996          0.961000
# 云与海                             0.0292         0.785          0.000000
# blind                           0.0652         0.141          0.000297
# What They'll Say About Us       0.0408         0.895          0.000150
# A Day At A Time                 0.0345         0.206          0.000003
#
#                            liveness  valence    tempo
# name
# John Brown's Song            0.1110   0.3860   63.696
# 云与海                          0.0648   0.2110  131.896
# blind                        0.0924   0.6860  150.091
# What They'll Say About Us    0.0874   0.0663  145.095
# A Day At A Time              0.3050   0.4380   90.029

# %%
#song = KNN_top_tracks_index['name'].loc[['Brown Eyed Girl']]

# %%
song = input('Enter song title: ')
# Out:
# Enter song title: Breaking Up Is Hard to Do

# %%
idx = KNN_top_tracks_index['id'].loc[['Teeth']]

# %%
song
# Out:
# 'Breaking Up Is Hard to Do'

# %%
idx
# Out:
# name
# Teeth    26wLOs3ZuHJa2Ihhx6QIE6
# Name: id, dtype: object

# %%
distances, indices = model_knn.kneighbors(KNN_top_tracks_proc.loc[song].to_numpy().reshape(1,-1), 11)
# Out:
# C:\Users\johnp\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   "X does not have valid feature names, but"

# %%
distances
# Out:
# array([[0.00000000e+00, 1.61304303e-12, 1.69519954e-12, 1.84041671e-12,
#         1.88127292e-12, 1.91946459e-12, 2.05613304e-12, 2.11575202e-12,
#         2.18325358e-12, 2.23665531e-12, 2.28572716e-12]])

# %%
indices[0]
# Out:
# array([     2,  40402, 188267, 374831,  43528, 105059, 198386,  41014,
#        226942,  51430,  42656], dtype=int64)

# %%
KNN_top_tracks_alpha[['name','artists']].loc[indices[0]].loc[KNN_top_tracks_alpha['name']!=song]
# Out:
#                                name  \
# 40402      Fell In Love With a Girl
# 188267                    Mano Lova
# 374831               Fica à Vontade
# 43528             Levanto Mis Manos
# 105059        Binnen Zonder Kloppen
# 198386  Déjame vivir (feat. Lamari)
# 41014                          2021
# 226942  Neighborhood #3 (Power Out)
# 51430     Como Tú (Magic Music Box)
# 42656                    Rise Again
#
#                                                   artists
# 40402                               ['The White Stripes']
# 188267                                         ['Pikaso']
# 374831  ['Mãolee', 'Ferrugem', 'Mc Poze do Rodo', 'Xam...
# 43528                                ['Samuel Hernández']
# 105059                                        ['De Dijk']
# 198386                       ['Jarabe De Palo', 'Lamari']
# 41014                                  ['FEDERALPRESSHA']
# 226942                                    ['Arcade Fire']
# 51430                                   ['León Larregui']
# 42656                                         ['Kamelot']

# %%
def recommender(song, model_knn, KNN_top_tracks_alpha, KNN_top_tracks_proc):
    
    
    distances, indices = model_knn.kneighbors(KNN_top_tracks_proc.loc[song].to_numpy().reshape(1,-1), 11)
        
    
    
    for i in indices:
        return (KNN_top_tracks_alpha[['name','artists']].loc[i].loc[KNN_top_tracks_alpha['name']!=song])

# %%
recommender(song, model_knn, KNN_top_tracks_alpha, KNN_top_tracks_proc)
# Out:
# C:\Users\johnp\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   "X does not have valid feature names, but"
#                                name  \
# 40402      Fell In Love With a Girl
# 188267                    Mano Lova
# 374831               Fica à Vontade
# 43528             Levanto Mis Manos
# 105059        Binnen Zonder Kloppen
# 198386  Déjame vivir (feat. Lamari)
# 41014                          2021
# 226942  Neighborhood #3 (Power Out)
# 51430     Como Tú (Magic Music Box)
# 42656                    Rise Again
#
#                                                   artists
# 40402                               ['The White Stripes']
# 188267                                         ['Pikaso']
# 374831  ['Mãolee', 'Ferrugem', 'Mc Poze do Rodo', 'Xam...
# 43528                                ['Samuel Hernández']
# 105059                                        ['De Dijk']
# 198386                       ['Jarabe De Palo', 'Lamari']
# 41014                                  ['FEDERALPRESSHA']
# 226942                                    ['Arcade Fire']
# 51430                                   ['León Larregui']
# 42656                                         ['Kamelot']

# %%
KNN_top_tracks.head()
# Out:
#                                                                     id  \
# name
# (What A) Wonderful World - Mono                 2G0GextMwZJLkNxcSZ7ZJ3
# Summertime Blues                                3oAWTk92mZBxKBOKf8mR5v
# Breaking Up Is Hard to Do                       2x6pbpjVGjiWCcH89IK8AX
# Georgia on My Mind - Original Master Recording  47mA6f44zxLtdATOoY7GjN
# Baby (You've Got What It Takes)                 0DICNd5XQ1og9UeYzxoNFV
#
#                                                                                           name  \
# name
# (What A) Wonderful World - Mono                                (What A) Wonderful World - Mono
# Summertime Blues                                                              Summertime Blues
# Breaking Up Is Hard to Do                                            Breaking Up Is Hard to Do
# Georgia on My Mind - Original Master Recording  Georgia on My Mind - Original Master Recording
# Baby (You've Got What It Takes)                                Baby (You've Got What It Takes)
#
#                                                 popularity  duration_ms  \
# name
# (What A) Wonderful World - Mono                         67       128787
# Summertime Blues                                        64       119360
# Breaking Up Is Hard to Do                               63       139200
# Georgia on My Mind - Original Master Recording          61       217415
# Baby (You've Got What It Takes)                         60       165760
#
#                                                 explicit  \
# name
# (What A) Wonderful World - Mono                        0
# Summertime Blues                                       0
# Breaking Up Is Hard to Do                              0
# Georgia on My Mind - Original Master Recording         0
# Baby (You've Got What It Takes)                        0
#
#                                                                              artists  \
# name
# (What A) Wonderful World - Mono                                        ['Sam Cooke']
# Summertime Blues                                                   ['Eddie Cochran']
# Breaking Up Is Hard to Do                                            ['Neil Sedaka']
# Georgia on My Mind - Original Master Recording                       ['Ray Charles']
# Baby (You've Got What It Takes)                 ['Dinah Washington', 'Brook Benton']
#
#                                                release_date  danceability  \
# name
# (What A) Wonderful World - Mono                  1960-02-01         0.686
# Summertime Blues                                 1960-05-01         0.714
# Breaking Up Is Hard to Do                        1960-12-30         0.743
# Georgia on My Mind - Original Master Recording   1960-09-01         0.138
# Baby (You've Got What It Takes)                  1960-07-05         0.670
#
#                                                 energy  key  loudness  mode  \
# name
# (What A) Wonderful World - Mono                  0.672   11    -5.523     1
# Summertime Blues                                 0.886   11    -8.629     0
# Breaking Up Is Hard to Do                        0.799    8    -5.466     0
# Georgia on My Mind - Original Master Recording   0.399    7    -8.756     1
# Baby (You've Got What It Takes)                  0.596    3    -9.347     1
#
#                                                 speechiness  acousticness  \
# name
# (What A) Wonderful World - Mono                      0.0323         0.700
# Summertime Blues                                     0.0554         0.116
# Breaking Up Is Hard to Do                            0.0375         0.699
# Georgia on My Mind - Original Master Recording       0.0311         0.782
# Baby (You've Got What It Takes)                      0.0627         0.852
#
#                                                 instrumentalness  liveness  \
# name
# (What A) Wonderful World - Mono                         0.000000    0.1350
# Summertime Blues                                        0.184000    0.1800
# Breaking Up Is Hard to Do                               0.000000    0.0635
# Georgia on My Mind - Original Master Recording          0.000004    0.1880
# Baby (You've Got What It Takes)                         0.002030    0.6530
#
#                                                 valence    tempo
# name
# (What A) Wonderful World - Mono                   0.857  128.550
# Summertime Blues                                  0.954  156.351
# Breaking Up Is Hard to Do                         0.965  116.112
# Georgia on My Mind - Original Master Recording    0.296  179.930
# Baby (You've Got What It Takes)                   0.813  133.396

# %%
KNN_top_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391661 entries, (What A) Wonderful World - Mono to A Day At A Time
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                391661 non-null  object
#  1   name              391661 non-null  object
#  2   popularity        391661 non-null  int64
#  3   duration_ms       391661 non-null  int64
#  4   explicit          391661 non-null  int64
#  5   artists           391661 non-null  object
#  6   release_date      391661 non-null  object
#  7   danceability      391661 non-null  float64
#  8   energy            391661 non-null  float64
#  9   key               391661 non-null  int64
#  10  loudness          391661 non-null  float64
#  11  mode              391661 non-null  int64
#  12  speechiness       391661 non-null  float64
#  13  acousticness      391661 non-null  float64
#  14  instrumentalness  391661 non-null  float64
#  15  liveness          391661 non-null  float64
#  16  valence           391661 non-null  float64
#  17  tempo             391661 non-null  float64
# dtypes: float64(9), int64(5), object(4)
# memory usage: 64.8+ MB

# %%
KNN_top_tracks_alpha.head()
# Out:
#                        id                                            name  \
# 0  2G0GextMwZJLkNxcSZ7ZJ3                 (What A) Wonderful World - Mono
# 1  3oAWTk92mZBxKBOKf8mR5v                                Summertime Blues
# 2  2x6pbpjVGjiWCcH89IK8AX                       Breaking Up Is Hard to Do
# 3  47mA6f44zxLtdATOoY7GjN  Georgia on My Mind - Original Master Recording
# 4  0DICNd5XQ1og9UeYzxoNFV                 Baby (You've Got What It Takes)
#
#    popularity  duration_ms  explicit                               artists  \
# 0          67       128787         0                         ['Sam Cooke']
# 1          64       119360         0                     ['Eddie Cochran']
# 2          63       139200         0                       ['Neil Sedaka']
# 3          61       217415         0                       ['Ray Charles']
# 4          60       165760         0  ['Dinah Washington', 'Brook Benton']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1960-02-01         0.686   0.672   11    -5.523     1       0.0323
# 1   1960-05-01         0.714   0.886   11    -8.629     0       0.0554
# 2   1960-12-30         0.743   0.799    8    -5.466     0       0.0375
# 3   1960-09-01         0.138   0.399    7    -8.756     1       0.0311
# 4   1960-07-05         0.670   0.596    3    -9.347     1       0.0627
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.700          0.000000    0.1350    0.857  128.550
# 1         0.116          0.184000    0.1800    0.954  156.351
# 2         0.699          0.000000    0.0635    0.965  116.112
# 3         0.782          0.000004    0.1880    0.296  179.930
# 4         0.852          0.002030    0.6530    0.813  133.396

# %%
KNN_top_tracks_proc.head()
# Out:
#                                                 popularity  duration_ms  \
# name
# (What A) Wonderful World - Mono                   2.154349     128787.0
# Summertime Blues                                  1.977253     119360.0
# Breaking Up Is Hard to Do                         1.918221     139200.0
# Georgia on My Mind - Original Master Recording    1.800158     217415.0
# Baby (You've Got What It Takes)                   1.741126     165760.0
#
#                                                 explicit  danceability  \
# name
# (What A) Wonderful World - Mono                      0.0      0.689451
# Summertime Blues                                     0.0      0.860380
# Breaking Up Is Hard to Do                            0.0      1.037413
# Georgia on My Mind - Original Master Recording       0.0     -2.655868
# Baby (You've Got What It Takes)                      0.0      0.591778
#
#                                                   energy       key  loudness  \
# name
# (What A) Wonderful World - Mono                -0.234264 -0.234264  0.879065
# Summertime Blues                               -0.234264 -0.234264  0.227086
# Breaking Up Is Hard to Do                      -0.234264 -0.234264  0.891030
# Georgia on My Mind - Original Master Recording -0.234264 -0.234264  0.200428
# Baby (You've Got What It Takes)                -0.234264 -0.234264  0.076371
#
#                                                     mode  speechiness  \
# name
# (What A) Wonderful World - Mono                -0.234264    -0.234264
# Summertime Blues                               -0.234264    -0.234264
# Breaking Up Is Hard to Do                      -0.234264    -0.234264
# Georgia on My Mind - Original Master Recording -0.234264    -0.234264
# Baby (You've Got What It Takes)                -0.234264    -0.234264
#
#                                                 acousticness  \
# name
# (What A) Wonderful World - Mono                    -0.234264
# Summertime Blues                                   -0.234264
# Breaking Up Is Hard to Do                          -0.234264
# Georgia on My Mind - Original Master Recording     -0.234264
# Baby (You've Got What It Takes)                    -0.234264
#
#                                                 instrumentalness  liveness  \
# name
# (What A) Wonderful World - Mono                        -0.234264    0.1350
# Summertime Blues                                       -0.234264    0.1800
# Breaking Up Is Hard to Do                              -0.234264    0.0635
# Georgia on My Mind - Original Master Recording         -0.234264    0.1880
# Baby (You've Got What It Takes)                        -0.234264    0.6530
#
#                                                  valence     tempo
# name
# (What A) Wonderful World - Mono                -0.234264  0.306697
# Summertime Blues                               -0.234264  1.253152
# Breaking Up Is Hard to Do                      -0.234264 -0.116741
# Georgia on My Mind - Original Master Recording -0.234264  2.055873
# Baby (You've Got What It Takes)                -0.234264  0.471674

# %%
#def recommender(df, song, n_neighbor=10):
 #   model_knn = NearestNeighbors(metric='cosine', algorithm = 'brute', n_neighbors = 11)
 #   model_knn.fit(KNN_top_tracks_proc)
    
 #   song = KNN_top_tracks.to_numpy()
    
  #  distances, indices = model_knn.kneighbors(song, 11)
    
  #  result = KNN_top_tracks.iloc[indices.flatten()]
 #   result["Distance"] = distance.flatten()
    
  #  return result

# %%
#df_result = recommender(KNN_top_tracks, "My Girl")

# %%
#df_result.head()
